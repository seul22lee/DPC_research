# %% [markdown]
# # TiDE model for melt pool temperature

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print("cuda is available")
else:
    print("cuda is NOT available")
torch.cuda.set_device(0)
    
import numpy as np
from tqdm import tqdm
from TiDE import TideModule, quantile_loss
import pickle

import matplotlib.pyplot as plt
import time
import copy

from moving_average import moving_average_1d
# Out:
# cuda is available

# %%
df_all = pd.read_csv('merged_df_2_99_temp_depth.csv')
df_all.shape
# Out:
# (610615, 12)

# %%
nan_rows = df_all[df_all.isna().any(axis=1)]
nan_rows
# Out:
#         time_index  melt_pool_temperature  melt_pool_depth  scanning_speed  \
# 6293    224.912038                    NaN              0.0             7.0
# 6294    224.947778                    NaN              NaN             7.0
# 12588   224.912038                    NaN              0.0             7.0
# 12589   224.947778                    NaN              NaN             7.0
# 18883   224.912038                    NaN              0.0             7.0
# ...            ...                    ...              ...             ...
# 598024  224.947778                    NaN              NaN             7.0
# 604318  224.912038                    NaN              0.0             7.0
# 604319  224.947778                    NaN              NaN             7.0
# 610613  224.912038                    NaN              0.0             7.0
# 610614  224.947778                    NaN              NaN             7.0
#
#                 X          Y    Z  Dist_to_nearest_X  Dist_to_nearest_Y  \
# 6293    17.029661 -18.742469  7.5           2.970339           1.257531
# 6294    17.018514 -18.933201  7.5           2.981486           1.066799
# 12588   17.029661 -18.742469  7.5           2.970339           1.257531
# 12589   17.018514 -18.933201  7.5           2.981486           1.066799
# 18883   17.029661 -18.742469  7.5           2.970339           1.257531
# ...           ...        ...  ...                ...                ...
# 598024  17.018514 -18.933201  7.5           2.981486           1.066799
# 604318  17.029661 -18.742469  7.5           2.970339           1.257531
# 604319  17.018514 -18.933201  7.5           2.981486           1.066799
# 610613  17.029661 -18.742469  7.5           2.970339           1.257531
# 610614  17.018514 -18.933201  7.5           2.981486           1.066799
#
#         Dist_to_nearest_Z  Laser_power  laser_power_number
# 6293                    0   614.885692                   2
# 6294                    0   614.893610                   2
# 12588                   0   633.345179                   3
# 12589                   0   633.341653                   3
# 18883                   0   683.646863                   4
# ...                   ...          ...                 ...
# 598024                  0   642.786355                  97
# 604318                  0   676.289806                  98
# 604319                  0   676.285789                  98
# 610613                  0   655.685110                  99
# 610614                  0   655.659718                  99
#
# [198 rows x 12 columns]

# %%
# slice data layer-by-layer

stop_flag = 0
safe_data_each_layer = []
start_location = 0
stop_location = 0

for i in range(df_all.shape[0]):
    try:
        layer_height = df_all["Z"][i]
        next_layer_height = df_all["Z"][i+1]
        
        if next_layer_height != layer_height:
            stop_location = i+1
            # append to safe_data_each_layer
            if stop_location - start_location >= 10:
                safe_data_each_layer.append(df_all[start_location:stop_location])
            start_location = i+1
    except:
        stop_location = i
        safe_data_each_layer.append(df_all[start_location:stop_location])

# %%
augmented_data = pd.DataFrame(np.repeat(safe_data_each_layer[1][0:1],50,axis=0))

# %%
# remove NaN from each chunk and remove the numbers after the whole part is completed. append the first W terms in the beginning of each layer 
for i in range(len(safe_data_each_layer)):
    safe_data_each_layer[i] = safe_data_each_layer[i].dropna()
    safe_data_each_layer[i] = safe_data_each_layer[i][0:610]
    augmented_data = pd.concat([safe_data_each_layer[i][0:1]]*50,axis=0)
    safe_data_each_layer[i] = pd.concat([augmented_data, safe_data_each_layer[i]])

# %%
prior_temp = safe_data_each_layer[-1]["melt_pool_temperature"].to_numpy()
prior_depth = safe_data_each_layer[-1]["melt_pool_depth"].to_numpy()

# %%
# moving averge on melt pool temp and depth for each chunk
for i in range(len(safe_data_each_layer)):
    mp_temp_raw = safe_data_each_layer[i]["melt_pool_temperature"].to_numpy()
    mp_temp_mv = moving_average_1d(mp_temp_raw,4)
    mp_temp = copy.deepcopy(mp_temp_raw)
    mp_temp[1:-2] = mp_temp_mv
    safe_data_each_layer[i]["melt_pool_temperature"] = mp_temp
    
    mp_depth_raw = safe_data_each_layer[i]["melt_pool_depth"].to_numpy()
    mp_depth_mv = moving_average_1d(mp_depth_raw,4)
    mp_depth = copy.deepcopy(mp_depth_raw)
    mp_depth[1:-2] = mp_depth_mv
    safe_data_each_layer[i]["melt_pool_depth"] = mp_depth

# %%
post_temp = safe_data_each_layer[-1]["melt_pool_temperature"].to_numpy()
post_depth = safe_data_each_layer[-1]["melt_pool_depth"].to_numpy()

plt.figure()
plt.plot(prior_temp)
plt.plot(post_temp)

plt.figure()
plt.plot(prior_depth)
plt.plot(post_depth)

# %%
# slice data in each chunk and append them into different attribute
total_segments = 0
window = 50
P = 50

for i in range(len(safe_data_each_layer)):
    total_segments = total_segments + safe_data_each_layer[i].shape[0] - window - P

# %%
total_segments
# Out:
# 540484

# %%
# slice each layers and assign them into segments
loc_X = np.zeros((1,total_segments, window + P))
loc_Y = np.zeros((1,total_segments, window + P))
loc_Z = np.zeros((1,total_segments, window + P))
dist_X = np.zeros((1,total_segments, window + P))
dist_Y = np.zeros((1,total_segments, window + P))
scan_spd = np.zeros((1,total_segments, window + P))
laser_power = np.zeros((1,total_segments, window + P))
laser_number = np.zeros((1,total_segments, window + P))
mp_temp = np.zeros((1,total_segments, window + P))
mp_depth = np.zeros((1,total_segments, window + P))



k = 0
for i in range(len(safe_data_each_layer)):
    for j in range(safe_data_each_layer[i].shape[0]-window-P):
        loc_X[0,k,:] = safe_data_each_layer[i]["X"][j:j+window+P]
        loc_Y[0,k,:] = safe_data_each_layer[i]["Y"][j:j+window+P]
        loc_Z[0,k,:] = safe_data_each_layer[i]["Z"][j:j+window+P]
        dist_X[0,k,:] = safe_data_each_layer[i]["Dist_to_nearest_X"][j:j+window+P]
        dist_Y[0,k,:] = safe_data_each_layer[i]["Dist_to_nearest_Y"][j:j+window+P]
        scan_spd[0,k,:] = safe_data_each_layer[i]["scanning_speed"][j:j+window+P]
        laser_power[0,k,:] = safe_data_each_layer[i]["Laser_power"][j:j+window+P]
        laser_number[0,k,:] = safe_data_each_layer[i]["laser_power_number"][j:j+window+P]
        # response
        mp_temp[0,k,:] = safe_data_each_layer[i]["melt_pool_temperature"][j:j+window+P]
        mp_depth[0,k,:] = safe_data_each_layer[i]["melt_pool_depth"][j:j+window+P]
        
        k += 1

# %%
# concat attributes
all_X = np.concatenate([loc_Z, dist_X, dist_Y, laser_power], axis = 0).transpose(1,2,0)
all_Y = np.concatenate([mp_temp, mp_depth], axis = 0).transpose(1,2,0)

# %%
class scalers():
    def __init__(self,x_max, x_min, y_max, y_min) -> None:
        self.x_max = x_max
        self.x_min = x_min
        self.y_max = y_max
        self.y_min = y_min
        
        return None
    
    def scaler_x(self, x_original, dim_id = -1):
        if dim_id == -1:
            x_s = -1 + 2 * ((x_original - self.x_min) / (self.x_max-self.x_min))
            return x_s
        else: 
            x_s = -1 + 2 * (x_original - self.x_min[0,dim_id]) / (self.x_max[0,dim_id] - self.x_min[0,dim_id])
            return x_s
    
    def inv_scaler_x(self, x_s, dim_id = -1):
        
        if dim_id == -1:
            x_original = (x_s + 1)*0.5*(self.x_max-self.x_min) + self.x_min
            return x_original
        else: 
            x_original = (x_s + 1)*0.5*(self.x_max[0,dim_id] - self.x_min[0,dim_id]) + self.x_min[0,dim_id]
            return x_original
        
    def scaler_y(self, y_original):
        return -1 + 2 * ((y_original - self.y_min) / (self.y_max-self.y_min))
    
    def inv_scaler_y(self, y_s):
        return (y_s + 1)*0.5*(self.y_max-self.y_min) + self.y_min

# %%
x_max = np.max(all_X,axis=(0,1)).reshape(1,1,-1)
x_min = np.min(all_X,axis=(0,1)).reshape(1,1,-1)
y_max = np.max(all_Y,axis=(0,1)).reshape(1,1,-1)
y_min = np.min(all_Y,axis=(0,1)).reshape(1,1,-1)

# %%
scaler = scalers(x_max, x_min, y_max, y_min)

x_s = scaler.scaler_x(all_X)
y_s = scaler.scaler_y(all_Y)

# %% [markdown]
# ### Knit data to the required format for training input and output

# %%
cutoff_ratio = 0.9
cutoff_index = int(np.round(cutoff_ratio*x_s.shape[0]))

x_s_train = x_s[:cutoff_index, :, :]
y_s_train = y_s[:cutoff_index, :, :]

x_s_val = x_s[cutoff_index:, :,: ]
y_s_val = y_s[cutoff_index:, :,:]

x_s_train.shape
# Out:
# (486436, 100, 4)

# %%
# ====================== training set =============================================


x_s_train_covariates = x_s_train
y_s_train_past = y_s_train[:,:window,:]
y_s_train_target = y_s_train[:,P:,:]
    

    
# ===================== validation set ============================================


x_s_val_covariates = x_s_val
y_s_val_past = y_s_val[:,:window,:]
y_s_val_target = y_s_val[:,P:,:]

# %%
input_past = torch.tensor(np.concatenate((y_s_train_past,x_s_train_covariates[:,:window,:]),axis=2),dtype=torch.float32).to(device)
input_future = torch.tensor(x_s_train_covariates[:,-P:,:], dtype=torch.float32).to(device)
input_target = torch.tensor(y_s_train_target,dtype=torch.float32).to(device)

val_past = torch.tensor(np.concatenate((y_s_val_past,x_s_val_covariates[:,:window,:]),axis=2),dtype=torch.float32).to(device)
val_future = torch.tensor(x_s_val_covariates[:,-P:,:], dtype=torch.float32).to(device)
val_target = torch.tensor(y_s_val_target,dtype=torch.float32).to(device)

Val_in = [val_past, val_future,None]

print(f"input past shape:{input_past.shape}, input future shape:{input_future.shape}, input target shape:{input_target.shape}")
print(f"val past shape:{val_past.shape}, val future shape:{val_future.shape}, val target shape:{val_target.shape}")
# Out:
# input past shape:torch.Size([486436, 50, 6]), input future shape:torch.Size([486436, 50, 4]), input target shape:torch.Size([486436, 50, 2])
# val past shape:torch.Size([54048, 50, 6]), val future shape:torch.Size([54048, 50, 4]), val target shape:torch.Size([54048, 50, 2])

# %% [markdown]
# ### Setup ensemble training model

# %%
output_dim = 2
future_cov_dim = 4

TiDE_MP = TideModule(
        input_dim = output_dim + future_cov_dim,
        output_dim = output_dim,
        future_cov_dim = future_cov_dim,
        static_cov_dim = 0,
        input_chunck_length = window,
        output_chunk_length = P,
        nr_params = 3,
        num_encoder_layers = 1,
        num_decoder_layers = 1,
        decoder_output_dim = 16,
        hidden_size = 128,
        temporal_decoder_hidden = 32,
        temporal_width_past = 4,
        temporal_width_future = 4,
        use_layer_norm = True,
        dropout = 0.2,
    ).to(device)

# # Define optimizer, loss function, and metrics
# optimizer = torch.optim.Adam(TiDE_MP.parameters(),lr=0.001,weight_decay=0.001)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)
# criterion = quantile_loss
# #criterion = torch.nn.MSELoss()
# num_epoch = 250

# Define optimizer, loss function, and metrics
optimizer = torch.optim.Adam(TiDE_MP.parameters(),lr=0.001,weight_decay=0.001*0.75)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.95)
criterion = quantile_loss
#criterion = torch.nn.MSELoss()
num_epoch = 300

# %%
import random
import numpy as np
import torch

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

n_ensemble = 7
ensemble_seeds = [200 + i for i in range(n_ensemble)]  # 원하는 seed 규칙
ensemble_models = []
ensemble_best_states = []
ensemble_train_losses = []
ensemble_val_losses = []

# %%
# Create DataLoader for training data
train_dataset = TensorDataset(input_past, input_future,input_target)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)

best_model = None
best_validation_loss = float("inf")

save_train_loss = np.zeros(num_epoch)
save_val_loss = np.zeros(num_epoch)

# %%
for ens_id, seed in enumerate(ensemble_seeds):

    print(f"\n====== Ensemble model {ens_id+1}/{n_ensemble} | seed={seed} ======")
    set_seed(seed)

    # -------- model init --------
    TiDE_MP = TideModule(
        input_dim = output_dim + future_cov_dim,
        output_dim = output_dim,
        future_cov_dim = future_cov_dim,
        static_cov_dim = 0,
        input_chunck_length = window,
        output_chunk_length = P,
        nr_params = 3,
        num_encoder_layers = 1,
        num_decoder_layers = 1,
        decoder_output_dim = 16,
        hidden_size = 128,
        temporal_decoder_hidden = 32,
        temporal_width_past = 4,
        temporal_width_future = 4,
        use_layer_norm = True,
        dropout = 0.2,
    ).to(device)

    optimizer = torch.optim.Adam(
        TiDE_MP.parameters(), lr=0.001, weight_decay=0.001 * 0.75
    )
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.95)
    criterion = quantile_loss

    best_validation_loss = float("inf")
    best_model = None

    save_train_loss = np.zeros(num_epoch)
    save_val_loss = np.zeros(num_epoch)

    # -------- training loop --------
    for epoch in range(num_epoch):

        epoch_train_loss = 0.0
        n_batch = 0

        for input_past, input_future, input_target in train_loader:
            x_in = [input_past, input_future, None]

            TiDE_MP.train()
            optimizer.zero_grad()

            output = TiDE_MP(x_in)
            quantiles = [0.1, 0.5, 0.9]
            loss = criterion(output, input_target, quantiles)

            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item()
            n_batch += 1

        epoch_train_loss /= n_batch

        TiDE_MP.eval()
        with torch.no_grad():
            val_out = TiDE_MP(Val_in)
            val_loss = criterion(val_out, val_target, quantiles)

        if val_loss < best_validation_loss:
            best_validation_loss = val_loss
            best_model = copy.deepcopy(TiDE_MP.state_dict())

        save_train_loss[epoch] = epoch_train_loss
        save_val_loss[epoch] = val_loss.item()

        scheduler.step()

        print(
            f"[Ens {ens_id+1}] Epoch={epoch}, "
            f"Train={epoch_train_loss:.4f}, Val={val_loss:.4f}"
        )

    # -------- ensemble 결과 저장 --------
    ensemble_best_states.append(best_model)
    ensemble_train_losses.append(save_train_loss)
    ensemble_val_losses.append(save_val_loss)

    # ====== 🔥 중간 저장 ======
    sys_params = dict()
    sys_params["x_max"] = x_max
    sys_params["x_min"] = x_min
    sys_params["y_max"] = y_max
    sys_params["y_min"] = y_min
    sys_params["models_state_dict"] = ensemble_best_states
    sys_params["P"] = P
    sys_params["window"] = window
    sys_params["seeds"] = ensemble_seeds[:len(ensemble_best_states)]
    sys_params["n_ensemble"] = len(ensemble_best_states)

    path = ''
    save_name = f'TiDE_params_ensemble_partial_{len(ensemble_best_states)}.pkl'

    with open(path + save_name, 'wb') as f:
        pickle.dump(sys_params, f)

    print(f"✅ Saved partial ensemble: {save_name}")

    # ====== GPU 정리 ======
    del TiDE_MP
    torch.cuda.empty_cache()
# Out:
# ====== Ensemble model 1/7 | seed=200 ======
# [Ens 1] Epoch=0, Train=0.0453, Val=0.0240
# [Ens 1] Epoch=1, Train=0.0215, Val=0.0205
# [Ens 1] Epoch=2, Train=0.0204, Val=0.0202
# [Ens 1] Epoch=3, Train=0.0196, Val=0.0190
# [Ens 1] Epoch=4, Train=0.0191, Val=0.0183
# [Ens 1] Epoch=5, Train=0.0189, Val=0.0180
# [Ens 1] Epoch=6, Train=0.0186, Val=0.0187
# [Ens 1] Epoch=7, Train=0.0185, Val=0.0188
# [Ens 1] Epoch=8, Train=0.0184, Val=0.0194
# [Ens 1] Epoch=9, Train=0.0183, Val=0.0188
# [Ens 1] Epoch=10, Train=0.0182, Val=0.0190
# [Ens 1] Epoch=11, Train=0.0181, Val=0.0191
# [Ens 1] Epoch=12, Train=0.0180, Val=0.0178
# [Ens 1] Epoch=13, Train=0.0180, Val=0.0172
# [Ens 1] Epoch=14, Train=0.0178, Val=0.0173
# [Ens 1] Epoch=15, Train=0.0178, Val=0.0182
# [Ens 1] Epoch=16, Train=0.0176, Val=0.0197
# [Ens 1] Epoch=17, Train=0.0176, Val=0.0177
# [Ens 1] Epoch=18, Train=0.0175, Val=0.0171
# [Ens 1] Epoch=19, Train=0.0175, Val=0.0175
# [Ens 1] Epoch=20, Train=0.0174, Val=0.0191
# [Ens 1] Epoch=21, Train=0.0174, Val=0.0174
# [Ens 1] Epoch=22, Train=0.0173, Val=0.0170
# [Ens 1] Epoch=23, Train=0.0173, Val=0.0206
# [Ens 1] Epoch=24, Train=0.0173, Val=0.0165
# [Ens 1] Epoch=25, Train=0.0172, Val=0.0172
# [Ens 1] Epoch=26, Train=0.0171, Val=0.0171
# [Ens 1] Epoch=27, Train=0.0171, Val=0.0170
# [Ens 1] Epoch=28, Train=0.0170, Val=0.0176
# [Ens 1] Epoch=29, Train=0.0171, Val=0.0166
# [Ens 1] Epoch=30, Train=0.0170, Val=0.0172
# [Ens 1] Epoch=31, Train=0.0170, Val=0.0174
# [Ens 1] Epoch=32, Train=0.0169, Val=0.0178
# [Ens 1] Epoch=33, Train=0.0169, Val=0.0163
# [Ens 1] Epoch=34, Train=0.0168, Val=0.0167
# [Ens 1] Epoch=35, Train=0.0169, Val=0.0163
# [Ens 1] Epoch=36, Train=0.0168, Val=0.0166
# [Ens 1] Epoch=37, Train=0.0168, Val=0.0165
# [Ens 1] Epoch=38, Train=0.0167, Val=0.0167
# [Ens 1] Epoch=39, Train=0.0167, Val=0.0184
# [Ens 1] Epoch=40, Train=0.0167, Val=0.0162
# [Ens 1] Epoch=41, Train=0.0166, Val=0.0160
# [Ens 1] Epoch=42, Train=0.0166, Val=0.0163
# [Ens 1] Epoch=43, Train=0.0166, Val=0.0164
# [Ens 1] Epoch=44, Train=0.0165, Val=0.0171
# [Ens 1] Epoch=45, Train=0.0166, Val=0.0163
# [Ens 1] Epoch=46, Train=0.0165, Val=0.0163
# [Ens 1] Epoch=47, Train=0.0165, Val=0.0162
# [Ens 1] Epoch=48, Train=0.0164, Val=0.0165
# [Ens 1] Epoch=49, Train=0.0164, Val=0.0175
# [Ens 1] Epoch=50, Train=0.0164, Val=0.0163
# [Ens 1] Epoch=51, Train=0.0164, Val=0.0160
# [Ens 1] Epoch=52, Train=0.0164, Val=0.0163
# [Ens 1] Epoch=53, Train=0.0164, Val=0.0170
# [Ens 1] Epoch=54, Train=0.0163, Val=0.0158
# [Ens 1] Epoch=55, Train=0.0163, Val=0.0160
# [Ens 1] Epoch=56, Train=0.0163, Val=0.0158
# [Ens 1] Epoch=57, Train=0.0163, Val=0.0160
# [Ens 1] Epoch=58, Train=0.0162, Val=0.0163
# [Ens 1] Epoch=59, Train=0.0162, Val=0.0161
# [Ens 1] Epoch=60, Train=0.0162, Val=0.0157
# [Ens 1] Epoch=61, Train=0.0162, Val=0.0159
# [Ens 1] Epoch=62, Train=0.0161, Val=0.0161
# [Ens 1] Epoch=63, Train=0.0161, Val=0.0155
# [Ens 1] Epoch=64, Train=0.0161, Val=0.0157
# [Ens 1] Epoch=65, Train=0.0161, Val=0.0158
# [Ens 1] Epoch=66, Train=0.0161, Val=0.0161
# [Ens 1] Epoch=67, Train=0.0161, Val=0.0158
# [Ens 1] Epoch=68, Train=0.0161, Val=0.0158
# [Ens 1] Epoch=69, Train=0.0160, Val=0.0160
# [Ens 1] Epoch=70, Train=0.0160, Val=0.0156
# [Ens 1] Epoch=71, Train=0.0160, Val=0.0160
# [Ens 1] Epoch=72, Train=0.0160, Val=0.0155
# [Ens 1] Epoch=73, Train=0.0160, Val=0.0157
# [Ens 1] Epoch=74, Train=0.0159, Val=0.0155
# [Ens 1] Epoch=75, Train=0.0159, Val=0.0153
# [Ens 1] Epoch=76, Train=0.0158, Val=0.0156
# [Ens 1] Epoch=77, Train=0.0158, Val=0.0155
# [Ens 1] Epoch=78, Train=0.0158, Val=0.0156
# [Ens 1] Epoch=79, Train=0.0158, Val=0.0152
# [Ens 1] Epoch=80, Train=0.0157, Val=0.0155
# [Ens 1] Epoch=81, Train=0.0157, Val=0.0153
# [Ens 1] Epoch=82, Train=0.0157, Val=0.0152
# [Ens 1] Epoch=83, Train=0.0157, Val=0.0152
# [Ens 1] Epoch=84, Train=0.0157, Val=0.0153
# [Ens 1] Epoch=85, Train=0.0157, Val=0.0153
# [Ens 1] Epoch=86, Train=0.0156, Val=0.0152
# [Ens 1] Epoch=87, Train=0.0156, Val=0.0153
# [Ens 1] Epoch=88, Train=0.0156, Val=0.0154
# [Ens 1] Epoch=89, Train=0.0156, Val=0.0152
# [Ens 1] Epoch=90, Train=0.0156, Val=0.0154
# [Ens 1] Epoch=91, Train=0.0156, Val=0.0153
# [Ens 1] Epoch=92, Train=0.0155, Val=0.0151
# [Ens 1] Epoch=93, Train=0.0154, Val=0.0153
# [Ens 1] Epoch=94, Train=0.0154, Val=0.0154
# [Ens 1] Epoch=95, Train=0.0154, Val=0.0153
# [Ens 1] Epoch=96, Train=0.0154, Val=0.0152
# [Ens 1] Epoch=97, Train=0.0154, Val=0.0152
# [Ens 1] Epoch=98, Train=0.0153, Val=0.0151
# [Ens 1] Epoch=99, Train=0.0153, Val=0.0149
# [Ens 1] Epoch=100, Train=0.0153, Val=0.0150
# [Ens 1] Epoch=101, Train=0.0152, Val=0.0147
# [Ens 1] Epoch=102, Train=0.0152, Val=0.0149
# [Ens 1] Epoch=103, Train=0.0152, Val=0.0147
# [Ens 1] Epoch=104, Train=0.0152, Val=0.0148
# [Ens 1] Epoch=105, Train=0.0152, Val=0.0149
# [Ens 1] Epoch=106, Train=0.0151, Val=0.0147
# [Ens 1] Epoch=107, Train=0.0151, Val=0.0148
# [Ens 1] Epoch=108, Train=0.0151, Val=0.0150
# [Ens 1] Epoch=109, Train=0.0151, Val=0.0149
# [Ens 1] Epoch=110, Train=0.0151, Val=0.0148
# [Ens 1] Epoch=111, Train=0.0150, Val=0.0146
# [Ens 1] Epoch=112, Train=0.0150, Val=0.0149
# [Ens 1] Epoch=113, Train=0.0150, Val=0.0148
# [Ens 1] Epoch=114, Train=0.0150, Val=0.0146
# [Ens 1] Epoch=115, Train=0.0150, Val=0.0149
# [Ens 1] Epoch=116, Train=0.0150, Val=0.0145
# [Ens 1] Epoch=117, Train=0.0150, Val=0.0149
# [Ens 1] Epoch=118, Train=0.0149, Val=0.0145
# [Ens 1] Epoch=119, Train=0.0149, Val=0.0148
# [Ens 1] Epoch=120, Train=0.0148, Val=0.0144
# [Ens 1] Epoch=121, Train=0.0147, Val=0.0145
# [Ens 1] Epoch=122, Train=0.0146, Val=0.0143
# [Ens 1] Epoch=123, Train=0.0145, Val=0.0141
# [Ens 1] Epoch=124, Train=0.0145, Val=0.0143
# [Ens 1] Epoch=125, Train=0.0144, Val=0.0140
# [Ens 1] Epoch=126, Train=0.0144, Val=0.0138
# [Ens 1] Epoch=127, Train=0.0143, Val=0.0140
# [Ens 1] Epoch=128, Train=0.0143, Val=0.0140
# [Ens 1] Epoch=129, Train=0.0142, Val=0.0139
# [Ens 1] Epoch=130, Train=0.0142, Val=0.0139
# [Ens 1] Epoch=131, Train=0.0141, Val=0.0136
# [Ens 1] Epoch=132, Train=0.0141, Val=0.0135
# [Ens 1] Epoch=133, Train=0.0140, Val=0.0135
# [Ens 1] Epoch=134, Train=0.0140, Val=0.0137
# [Ens 1] Epoch=135, Train=0.0139, Val=0.0136
# [Ens 1] Epoch=136, Train=0.0139, Val=0.0134
# [Ens 1] Epoch=137, Train=0.0139, Val=0.0138
# [Ens 1] Epoch=138, Train=0.0138, Val=0.0137
# [Ens 1] Epoch=139, Train=0.0138, Val=0.0134
# [Ens 1] Epoch=140, Train=0.0138, Val=0.0133
# [Ens 1] Epoch=141, Train=0.0137, Val=0.0136
# [Ens 1] Epoch=142, Train=0.0137, Val=0.0133
# [Ens 1] Epoch=143, Train=0.0137, Val=0.0133
# [Ens 1] Epoch=144, Train=0.0136, Val=0.0131
# [Ens 1] Epoch=145, Train=0.0136, Val=0.0131
# [Ens 1] Epoch=146, Train=0.0136, Val=0.0136
# [Ens 1] Epoch=147, Train=0.0136, Val=0.0132
# [Ens 1] Epoch=148, Train=0.0135, Val=0.0130
# [Ens 1] Epoch=149, Train=0.0135, Val=0.0131
# [Ens 1] Epoch=150, Train=0.0135, Val=0.0132
# [Ens 1] Epoch=151, Train=0.0135, Val=0.0132
# [Ens 1] Epoch=152, Train=0.0134, Val=0.0131
# [Ens 1] Epoch=153, Train=0.0134, Val=0.0131
# [Ens 1] Epoch=154, Train=0.0134, Val=0.0130
# [Ens 1] Epoch=155, Train=0.0134, Val=0.0130
# [Ens 1] Epoch=156, Train=0.0134, Val=0.0129
# [Ens 1] Epoch=157, Train=0.0133, Val=0.0128
# [Ens 1] Epoch=158, Train=0.0133, Val=0.0131
# [Ens 1] Epoch=159, Train=0.0133, Val=0.0129
# [Ens 1] Epoch=160, Train=0.0133, Val=0.0128
# [Ens 1] Epoch=161, Train=0.0133, Val=0.0128
# [Ens 1] Epoch=162, Train=0.0132, Val=0.0130
# [Ens 1] Epoch=163, Train=0.0132, Val=0.0129
# [Ens 1] Epoch=164, Train=0.0132, Val=0.0128
# [Ens 1] Epoch=165, Train=0.0132, Val=0.0128
# [Ens 1] Epoch=166, Train=0.0132, Val=0.0127
# [Ens 1] Epoch=167, Train=0.0132, Val=0.0129
# [Ens 1] Epoch=168, Train=0.0131, Val=0.0128
# [Ens 1] Epoch=169, Train=0.0131, Val=0.0128
# [Ens 1] Epoch=170, Train=0.0131, Val=0.0129
# [Ens 1] Epoch=171, Train=0.0131, Val=0.0126
# [Ens 1] Epoch=172, Train=0.0131, Val=0.0126
# [Ens 1] Epoch=173, Train=0.0131, Val=0.0127
# [Ens 1] Epoch=174, Train=0.0131, Val=0.0127
# [Ens 1] Epoch=175, Train=0.0131, Val=0.0127
# [Ens 1] Epoch=176, Train=0.0131, Val=0.0126
# [Ens 1] Epoch=177, Train=0.0130, Val=0.0127
# [Ens 1] Epoch=178, Train=0.0130, Val=0.0126
# [Ens 1] Epoch=179, Train=0.0130, Val=0.0126
# [Ens 1] Epoch=180, Train=0.0130, Val=0.0125
# [Ens 1] Epoch=181, Train=0.0130, Val=0.0126
# [Ens 1] Epoch=182, Train=0.0130, Val=0.0127
# [Ens 1] Epoch=183, Train=0.0130, Val=0.0127
# [Ens 1] Epoch=184, Train=0.0130, Val=0.0126
# [Ens 1] Epoch=185, Train=0.0130, Val=0.0127
# [Ens 1] Epoch=186, Train=0.0130, Val=0.0128
# [Ens 1] Epoch=187, Train=0.0130, Val=0.0126
# [Ens 1] Epoch=188, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=189, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=190, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=191, Train=0.0129, Val=0.0126
# [Ens 1] Epoch=192, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=193, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=194, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=195, Train=0.0129, Val=0.0124
# [Ens 1] Epoch=196, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=197, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=198, Train=0.0129, Val=0.0124
# [Ens 1] Epoch=199, Train=0.0129, Val=0.0125
# [Ens 1] Epoch=200, Train=0.0128, Val=0.0124
# [Ens 1] Epoch=201, Train=0.0128, Val=0.0125
# [Ens 1] Epoch=202, Train=0.0128, Val=0.0126
# [Ens 1] Epoch=203, Train=0.0128, Val=0.0124
# [Ens 1] Epoch=204, Train=0.0128, Val=0.0124
# [Ens 1] Epoch=205, Train=0.0128, Val=0.0124
# [Ens 1] Epoch=206, Train=0.0128, Val=0.0123
# [Ens 1] Epoch=207, Train=0.0127, Val=0.0123
# [Ens 1] Epoch=208, Train=0.0127, Val=0.0124
# [Ens 1] Epoch=209, Train=0.0127, Val=0.0123
# [Ens 1] Epoch=210, Train=0.0127, Val=0.0123
# [Ens 1] Epoch=211, Train=0.0127, Val=0.0123
# [Ens 1] Epoch=212, Train=0.0127, Val=0.0122
# [Ens 1] Epoch=213, Train=0.0127, Val=0.0122
# [Ens 1] Epoch=214, Train=0.0126, Val=0.0122
# [Ens 1] Epoch=215, Train=0.0126, Val=0.0123
# [Ens 1] Epoch=216, Train=0.0126, Val=0.0122
# [Ens 1] Epoch=217, Train=0.0126, Val=0.0122
# [Ens 1] Epoch=218, Train=0.0126, Val=0.0122
# [Ens 1] Epoch=219, Train=0.0126, Val=0.0122
# [Ens 1] Epoch=220, Train=0.0126, Val=0.0121
# [Ens 1] Epoch=221, Train=0.0126, Val=0.0121
# [Ens 1] Epoch=222, Train=0.0126, Val=0.0122
# [Ens 1] Epoch=223, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=224, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=225, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=226, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=227, Train=0.0125, Val=0.0122
# [Ens 1] Epoch=228, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=229, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=230, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=231, Train=0.0125, Val=0.0122
# [Ens 1] Epoch=232, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=233, Train=0.0125, Val=0.0122
# [Ens 1] Epoch=234, Train=0.0125, Val=0.0120
# [Ens 1] Epoch=235, Train=0.0125, Val=0.0122
# [Ens 1] Epoch=236, Train=0.0125, Val=0.0121
# [Ens 1] Epoch=237, Train=0.0125, Val=0.0120
# [Ens 1] Epoch=238, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=239, Train=0.0124, Val=0.0121
# [Ens 1] Epoch=240, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=241, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=242, Train=0.0124, Val=0.0121
# [Ens 1] Epoch=243, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=244, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=245, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=246, Train=0.0124, Val=0.0121
# [Ens 1] Epoch=247, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=248, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=249, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=250, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=251, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=252, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=253, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=254, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=255, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=256, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=257, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=258, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=259, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=260, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=261, Train=0.0124, Val=0.0120
# [Ens 1] Epoch=262, Train=0.0124, Val=0.0119
# [Ens 1] Epoch=263, Train=0.0123, Val=0.0120
# [Ens 1] Epoch=264, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=265, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=266, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=267, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=268, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=269, Train=0.0123, Val=0.0120
# [Ens 1] Epoch=270, Train=0.0123, Val=0.0120
# [Ens 1] Epoch=271, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=272, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=273, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=274, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=275, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=276, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=277, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=278, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=279, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=280, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=281, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=282, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=283, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=284, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=285, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=286, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=287, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=288, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=289, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=290, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=291, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=292, Train=0.0123, Val=0.0120
# [Ens 1] Epoch=293, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=294, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=295, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=296, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=297, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=298, Train=0.0123, Val=0.0119
# [Ens 1] Epoch=299, Train=0.0123, Val=0.0119
# ✅ Saved partial ensemble: TiDE_params_ensemble_partial_1.pkl
#
# ====== Ensemble model 2/7 | seed=201 ======
# [Ens 2] Epoch=0, Train=0.0422, Val=0.0214
# [Ens 2] Epoch=1, Train=0.0212, Val=0.0195
# [Ens 2] Epoch=2, Train=0.0203, Val=0.0206
# [Ens 2] Epoch=3, Train=0.0199, Val=0.0207
# [Ens 2] Epoch=4, Train=0.0193, Val=0.0183
# [Ens 2] Epoch=5, Train=0.0189, Val=0.0189
# [Ens 2] Epoch=6, Train=0.0187, Val=0.0190
# [Ens 2] Epoch=7, Train=0.0186, Val=0.0186
# [Ens 2] Epoch=8, Train=0.0185, Val=0.0184
# [Ens 2] Epoch=9, Train=0.0185, Val=0.0178
# [Ens 2] Epoch=10, Train=0.0184, Val=0.0182
# [Ens 2] Epoch=11, Train=0.0184, Val=0.0190
# [Ens 2] Epoch=12, Train=0.0183, Val=0.0182
# [Ens 2] Epoch=13, Train=0.0183, Val=0.0179
# [Ens 2] Epoch=14, Train=0.0182, Val=0.0175
# [Ens 2] Epoch=15, Train=0.0182, Val=0.0174
# [Ens 2] Epoch=16, Train=0.0181, Val=0.0175
# [Ens 2] Epoch=17, Train=0.0182, Val=0.0184
# [Ens 2] Epoch=18, Train=0.0181, Val=0.0177
# [Ens 2] Epoch=19, Train=0.0180, Val=0.0180
# [Ens 2] Epoch=20, Train=0.0180, Val=0.0183
# [Ens 2] Epoch=21, Train=0.0180, Val=0.0193
# [Ens 2] Epoch=22, Train=0.0179, Val=0.0176
# [Ens 2] Epoch=23, Train=0.0179, Val=0.0178
# [Ens 2] Epoch=24, Train=0.0178, Val=0.0185
# [Ens 2] Epoch=25, Train=0.0178, Val=0.0185
# [Ens 2] Epoch=26, Train=0.0177, Val=0.0170
# [Ens 2] Epoch=27, Train=0.0177, Val=0.0175
# [Ens 2] Epoch=28, Train=0.0176, Val=0.0173
# [Ens 2] Epoch=29, Train=0.0176, Val=0.0174
# [Ens 2] Epoch=30, Train=0.0175, Val=0.0181
# [Ens 2] Epoch=31, Train=0.0175, Val=0.0186
# [Ens 2] Epoch=32, Train=0.0174, Val=0.0170
# [Ens 2] Epoch=33, Train=0.0174, Val=0.0169
# [Ens 2] Epoch=34, Train=0.0173, Val=0.0179
# [Ens 2] Epoch=35, Train=0.0173, Val=0.0166
# [Ens 2] Epoch=36, Train=0.0172, Val=0.0167
# [Ens 2] Epoch=37, Train=0.0171, Val=0.0169
# [Ens 2] Epoch=38, Train=0.0171, Val=0.0167
# [Ens 2] Epoch=39, Train=0.0170, Val=0.0165
# [Ens 2] Epoch=40, Train=0.0169, Val=0.0174
# [Ens 2] Epoch=41, Train=0.0169, Val=0.0163
# [Ens 2] Epoch=42, Train=0.0168, Val=0.0163
# [Ens 2] Epoch=43, Train=0.0168, Val=0.0179
# [Ens 2] Epoch=44, Train=0.0167, Val=0.0164
# [Ens 2] Epoch=45, Train=0.0167, Val=0.0164
# [Ens 2] Epoch=46, Train=0.0166, Val=0.0163
# [Ens 2] Epoch=47, Train=0.0166, Val=0.0160
# [Ens 2] Epoch=48, Train=0.0166, Val=0.0163
# [Ens 2] Epoch=49, Train=0.0166, Val=0.0164
# [Ens 2] Epoch=50, Train=0.0165, Val=0.0165
# [Ens 2] Epoch=51, Train=0.0165, Val=0.0161
# [Ens 2] Epoch=52, Train=0.0164, Val=0.0162
# [Ens 2] Epoch=53, Train=0.0164, Val=0.0164
# [Ens 2] Epoch=54, Train=0.0164, Val=0.0166
# [Ens 2] Epoch=55, Train=0.0163, Val=0.0165
# [Ens 2] Epoch=56, Train=0.0163, Val=0.0166
# [Ens 2] Epoch=57, Train=0.0163, Val=0.0166
# [Ens 2] Epoch=58, Train=0.0162, Val=0.0160
# [Ens 2] Epoch=59, Train=0.0162, Val=0.0161
# [Ens 2] Epoch=60, Train=0.0162, Val=0.0161
# [Ens 2] Epoch=61, Train=0.0161, Val=0.0163
# [Ens 2] Epoch=62, Train=0.0161, Val=0.0158
# [Ens 2] Epoch=63, Train=0.0161, Val=0.0167
# [Ens 2] Epoch=64, Train=0.0160, Val=0.0161
# [Ens 2] Epoch=65, Train=0.0160, Val=0.0158
# [Ens 2] Epoch=66, Train=0.0159, Val=0.0155
# [Ens 2] Epoch=67, Train=0.0159, Val=0.0157
# [Ens 2] Epoch=68, Train=0.0159, Val=0.0160
# [Ens 2] Epoch=69, Train=0.0159, Val=0.0158
# [Ens 2] Epoch=70, Train=0.0158, Val=0.0154
# [Ens 2] Epoch=71, Train=0.0158, Val=0.0156
# [Ens 2] Epoch=72, Train=0.0158, Val=0.0154
# [Ens 2] Epoch=73, Train=0.0157, Val=0.0163
# [Ens 2] Epoch=74, Train=0.0157, Val=0.0153
# [Ens 2] Epoch=75, Train=0.0157, Val=0.0152
# [Ens 2] Epoch=76, Train=0.0157, Val=0.0151
# [Ens 2] Epoch=77, Train=0.0156, Val=0.0158
# [Ens 2] Epoch=78, Train=0.0156, Val=0.0158
# [Ens 2] Epoch=79, Train=0.0156, Val=0.0152
# [Ens 2] Epoch=80, Train=0.0155, Val=0.0152
# [Ens 2] Epoch=81, Train=0.0155, Val=0.0153
# [Ens 2] Epoch=82, Train=0.0155, Val=0.0148
# [Ens 2] Epoch=83, Train=0.0155, Val=0.0153
# [Ens 2] Epoch=84, Train=0.0154, Val=0.0150
# [Ens 2] Epoch=85, Train=0.0153, Val=0.0156
# [Ens 2] Epoch=86, Train=0.0153, Val=0.0149
# [Ens 2] Epoch=87, Train=0.0152, Val=0.0148
# [Ens 2] Epoch=88, Train=0.0151, Val=0.0146
# [Ens 2] Epoch=89, Train=0.0151, Val=0.0145
# [Ens 2] Epoch=90, Train=0.0151, Val=0.0143
# [Ens 2] Epoch=91, Train=0.0150, Val=0.0146
# [Ens 2] Epoch=92, Train=0.0150, Val=0.0142
# [Ens 2] Epoch=93, Train=0.0150, Val=0.0144
# [Ens 2] Epoch=94, Train=0.0149, Val=0.0146
# [Ens 2] Epoch=95, Train=0.0149, Val=0.0144
# [Ens 2] Epoch=96, Train=0.0148, Val=0.0143
# [Ens 2] Epoch=97, Train=0.0148, Val=0.0145
# [Ens 2] Epoch=98, Train=0.0147, Val=0.0140
# [Ens 2] Epoch=99, Train=0.0147, Val=0.0148
# [Ens 2] Epoch=100, Train=0.0146, Val=0.0142
# [Ens 2] Epoch=101, Train=0.0146, Val=0.0138
# [Ens 2] Epoch=102, Train=0.0145, Val=0.0138
# [Ens 2] Epoch=103, Train=0.0144, Val=0.0141
# [Ens 2] Epoch=104, Train=0.0144, Val=0.0158
# [Ens 2] Epoch=105, Train=0.0144, Val=0.0139
# [Ens 2] Epoch=106, Train=0.0143, Val=0.0145
# [Ens 2] Epoch=107, Train=0.0143, Val=0.0138
# [Ens 2] Epoch=108, Train=0.0142, Val=0.0138
# [Ens 2] Epoch=109, Train=0.0142, Val=0.0137
# [Ens 2] Epoch=110, Train=0.0142, Val=0.0138
# [Ens 2] Epoch=111, Train=0.0142, Val=0.0140
# [Ens 2] Epoch=112, Train=0.0141, Val=0.0149
# [Ens 2] Epoch=113, Train=0.0141, Val=0.0140
# [Ens 2] Epoch=114, Train=0.0141, Val=0.0136
# [Ens 2] Epoch=115, Train=0.0141, Val=0.0139
# [Ens 2] Epoch=116, Train=0.0140, Val=0.0134
# [Ens 2] Epoch=117, Train=0.0140, Val=0.0141
# [Ens 2] Epoch=118, Train=0.0140, Val=0.0136
# [Ens 2] Epoch=119, Train=0.0140, Val=0.0135
# [Ens 2] Epoch=120, Train=0.0139, Val=0.0134
# [Ens 2] Epoch=121, Train=0.0139, Val=0.0137
# [Ens 2] Epoch=122, Train=0.0139, Val=0.0133
# [Ens 2] Epoch=123, Train=0.0139, Val=0.0134
# [Ens 2] Epoch=124, Train=0.0139, Val=0.0135
# [Ens 2] Epoch=125, Train=0.0139, Val=0.0138
# [Ens 2] Epoch=126, Train=0.0138, Val=0.0134
# [Ens 2] Epoch=127, Train=0.0138, Val=0.0134
# [Ens 2] Epoch=128, Train=0.0138, Val=0.0132
# [Ens 2] Epoch=129, Train=0.0138, Val=0.0133
# [Ens 2] Epoch=130, Train=0.0138, Val=0.0133
# [Ens 2] Epoch=131, Train=0.0138, Val=0.0138
# [Ens 2] Epoch=132, Train=0.0137, Val=0.0132
# [Ens 2] Epoch=133, Train=0.0137, Val=0.0136
# [Ens 2] Epoch=134, Train=0.0137, Val=0.0132
# [Ens 2] Epoch=135, Train=0.0137, Val=0.0131
# [Ens 2] Epoch=136, Train=0.0137, Val=0.0132
# [Ens 2] Epoch=137, Train=0.0136, Val=0.0132
# [Ens 2] Epoch=138, Train=0.0136, Val=0.0131
# [Ens 2] Epoch=139, Train=0.0136, Val=0.0131
# [Ens 2] Epoch=140, Train=0.0136, Val=0.0133
# [Ens 2] Epoch=141, Train=0.0136, Val=0.0131
# [Ens 2] Epoch=142, Train=0.0136, Val=0.0131
# [Ens 2] Epoch=143, Train=0.0136, Val=0.0130
# [Ens 2] Epoch=144, Train=0.0135, Val=0.0133
# [Ens 2] Epoch=145, Train=0.0135, Val=0.0130
# [Ens 2] Epoch=146, Train=0.0135, Val=0.0132
# [Ens 2] Epoch=147, Train=0.0135, Val=0.0131
# [Ens 2] Epoch=148, Train=0.0135, Val=0.0130
# [Ens 2] Epoch=149, Train=0.0135, Val=0.0130
# [Ens 2] Epoch=150, Train=0.0135, Val=0.0131
# [Ens 2] Epoch=151, Train=0.0134, Val=0.0130
# [Ens 2] Epoch=152, Train=0.0134, Val=0.0129
# [Ens 2] Epoch=153, Train=0.0134, Val=0.0130
# [Ens 2] Epoch=154, Train=0.0134, Val=0.0129
# [Ens 2] Epoch=155, Train=0.0134, Val=0.0133
# [Ens 2] Epoch=156, Train=0.0134, Val=0.0130
# [Ens 2] Epoch=157, Train=0.0134, Val=0.0129
# [Ens 2] Epoch=158, Train=0.0133, Val=0.0130
# [Ens 2] Epoch=159, Train=0.0133, Val=0.0129
# [Ens 2] Epoch=160, Train=0.0133, Val=0.0129
# [Ens 2] Epoch=161, Train=0.0133, Val=0.0131
# [Ens 2] Epoch=162, Train=0.0133, Val=0.0129
# [Ens 2] Epoch=163, Train=0.0133, Val=0.0129
# [Ens 2] Epoch=164, Train=0.0133, Val=0.0128
# [Ens 2] Epoch=165, Train=0.0133, Val=0.0128
# [Ens 2] Epoch=166, Train=0.0132, Val=0.0128
# [Ens 2] Epoch=167, Train=0.0132, Val=0.0128
# [Ens 2] Epoch=168, Train=0.0132, Val=0.0128
# [Ens 2] Epoch=169, Train=0.0132, Val=0.0128
# [Ens 2] Epoch=170, Train=0.0132, Val=0.0128
# [Ens 2] Epoch=171, Train=0.0132, Val=0.0128
# [Ens 2] Epoch=172, Train=0.0132, Val=0.0128
# [Ens 2] Epoch=173, Train=0.0132, Val=0.0128
# [Ens 2] Epoch=174, Train=0.0132, Val=0.0127
# [Ens 2] Epoch=175, Train=0.0132, Val=0.0127
# [Ens 2] Epoch=176, Train=0.0132, Val=0.0127
# [Ens 2] Epoch=177, Train=0.0132, Val=0.0127
# [Ens 2] Epoch=178, Train=0.0131, Val=0.0127
# [Ens 2] Epoch=179, Train=0.0131, Val=0.0126
# [Ens 2] Epoch=180, Train=0.0131, Val=0.0127
# [Ens 2] Epoch=181, Train=0.0131, Val=0.0127
# [Ens 2] Epoch=182, Train=0.0131, Val=0.0126
# [Ens 2] Epoch=183, Train=0.0131, Val=0.0126
# [Ens 2] Epoch=184, Train=0.0131, Val=0.0127
# [Ens 2] Epoch=185, Train=0.0131, Val=0.0126
# [Ens 2] Epoch=186, Train=0.0131, Val=0.0127
# [Ens 2] Epoch=187, Train=0.0131, Val=0.0126
# [Ens 2] Epoch=188, Train=0.0130, Val=0.0125
# [Ens 2] Epoch=189, Train=0.0130, Val=0.0125
# [Ens 2] Epoch=190, Train=0.0130, Val=0.0125
# [Ens 2] Epoch=191, Train=0.0130, Val=0.0126
# [Ens 2] Epoch=192, Train=0.0130, Val=0.0126
# [Ens 2] Epoch=193, Train=0.0130, Val=0.0126
# [Ens 2] Epoch=194, Train=0.0130, Val=0.0126
# [Ens 2] Epoch=195, Train=0.0130, Val=0.0125
# [Ens 2] Epoch=196, Train=0.0130, Val=0.0125
# [Ens 2] Epoch=197, Train=0.0129, Val=0.0124
# [Ens 2] Epoch=198, Train=0.0129, Val=0.0124
# [Ens 2] Epoch=199, Train=0.0129, Val=0.0124
# [Ens 2] Epoch=200, Train=0.0129, Val=0.0124
# [Ens 2] Epoch=201, Train=0.0129, Val=0.0124
# [Ens 2] Epoch=202, Train=0.0129, Val=0.0124
# [Ens 2] Epoch=203, Train=0.0129, Val=0.0124
# [Ens 2] Epoch=204, Train=0.0128, Val=0.0123
# [Ens 2] Epoch=205, Train=0.0128, Val=0.0124
# [Ens 2] Epoch=206, Train=0.0128, Val=0.0124
# [Ens 2] Epoch=207, Train=0.0128, Val=0.0123
# [Ens 2] Epoch=208, Train=0.0128, Val=0.0123
# [Ens 2] Epoch=209, Train=0.0128, Val=0.0123
# [Ens 2] Epoch=210, Train=0.0128, Val=0.0124
# [Ens 2] Epoch=211, Train=0.0128, Val=0.0124
# [Ens 2] Epoch=212, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=213, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=214, Train=0.0127, Val=0.0123
# [Ens 2] Epoch=215, Train=0.0127, Val=0.0123
# [Ens 2] Epoch=216, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=217, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=218, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=219, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=220, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=221, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=222, Train=0.0127, Val=0.0123
# [Ens 2] Epoch=223, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=224, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=225, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=226, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=227, Train=0.0127, Val=0.0122
# [Ens 2] Epoch=228, Train=0.0126, Val=0.0122
# [Ens 2] Epoch=229, Train=0.0126, Val=0.0122
# [Ens 2] Epoch=230, Train=0.0126, Val=0.0122
# [Ens 2] Epoch=231, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=232, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=233, Train=0.0126, Val=0.0122
# [Ens 2] Epoch=234, Train=0.0126, Val=0.0122
# [Ens 2] Epoch=235, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=236, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=237, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=238, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=239, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=240, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=241, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=242, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=243, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=244, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=245, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=246, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=247, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=248, Train=0.0126, Val=0.0120
# [Ens 2] Epoch=249, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=250, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=251, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=252, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=253, Train=0.0126, Val=0.0121
# [Ens 2] Epoch=254, Train=0.0125, Val=0.0121
# [Ens 2] Epoch=255, Train=0.0126, Val=0.0120
# [Ens 2] Epoch=256, Train=0.0125, Val=0.0121
# [Ens 2] Epoch=257, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=258, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=259, Train=0.0125, Val=0.0121
# [Ens 2] Epoch=260, Train=0.0125, Val=0.0121
# [Ens 2] Epoch=261, Train=0.0125, Val=0.0121
# [Ens 2] Epoch=262, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=263, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=264, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=265, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=266, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=267, Train=0.0125, Val=0.0121
# [Ens 2] Epoch=268, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=269, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=270, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=271, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=272, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=273, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=274, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=275, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=276, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=277, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=278, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=279, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=280, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=281, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=282, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=283, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=284, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=285, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=286, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=287, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=288, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=289, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=290, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=291, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=292, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=293, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=294, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=295, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=296, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=297, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=298, Train=0.0125, Val=0.0120
# [Ens 2] Epoch=299, Train=0.0125, Val=0.0120
# ✅ Saved partial ensemble: TiDE_params_ensemble_partial_2.pkl
#
# ====== Ensemble model 3/7 | seed=202 ======
# [Ens 3] Epoch=0, Train=0.0470, Val=0.0217
# [Ens 3] Epoch=1, Train=0.0213, Val=0.0198
# [Ens 3] Epoch=2, Train=0.0202, Val=0.0187
# [Ens 3] Epoch=3, Train=0.0197, Val=0.0191
# [Ens 3] Epoch=4, Train=0.0192, Val=0.0195
# [Ens 3] Epoch=5, Train=0.0191, Val=0.0196
# [Ens 3] Epoch=6, Train=0.0189, Val=0.0186
# [Ens 3] Epoch=7, Train=0.0188, Val=0.0182
# [Ens 3] Epoch=8, Train=0.0187, Val=0.0183
# [Ens 3] Epoch=9, Train=0.0186, Val=0.0183
# [Ens 3] Epoch=10, Train=0.0186, Val=0.0182
# [Ens 3] Epoch=11, Train=0.0185, Val=0.0187
# [Ens 3] Epoch=12, Train=0.0184, Val=0.0191
# [Ens 3] Epoch=13, Train=0.0184, Val=0.0179
# [Ens 3] Epoch=14, Train=0.0183, Val=0.0185
# [Ens 3] Epoch=15, Train=0.0183, Val=0.0175
# [Ens 3] Epoch=16, Train=0.0182, Val=0.0182
# [Ens 3] Epoch=17, Train=0.0182, Val=0.0184
# [Ens 3] Epoch=18, Train=0.0181, Val=0.0189
# [Ens 3] Epoch=19, Train=0.0181, Val=0.0187
# [Ens 3] Epoch=20, Train=0.0181, Val=0.0174
# [Ens 3] Epoch=21, Train=0.0181, Val=0.0186
# [Ens 3] Epoch=22, Train=0.0180, Val=0.0177
# [Ens 3] Epoch=23, Train=0.0180, Val=0.0176
# [Ens 3] Epoch=24, Train=0.0179, Val=0.0181
# [Ens 3] Epoch=25, Train=0.0179, Val=0.0179
# [Ens 3] Epoch=26, Train=0.0178, Val=0.0181
# [Ens 3] Epoch=27, Train=0.0178, Val=0.0176
# [Ens 3] Epoch=28, Train=0.0177, Val=0.0173
# [Ens 3] Epoch=29, Train=0.0177, Val=0.0174
# [Ens 3] Epoch=30, Train=0.0176, Val=0.0184
# [Ens 3] Epoch=31, Train=0.0177, Val=0.0176
# [Ens 3] Epoch=32, Train=0.0176, Val=0.0180
# [Ens 3] Epoch=33, Train=0.0176, Val=0.0174
# [Ens 3] Epoch=34, Train=0.0175, Val=0.0180
# [Ens 3] Epoch=35, Train=0.0175, Val=0.0183
# [Ens 3] Epoch=36, Train=0.0174, Val=0.0176
# [Ens 3] Epoch=37, Train=0.0174, Val=0.0173
# [Ens 3] Epoch=38, Train=0.0174, Val=0.0178
# [Ens 3] Epoch=39, Train=0.0173, Val=0.0174
# [Ens 3] Epoch=40, Train=0.0173, Val=0.0170
# [Ens 3] Epoch=41, Train=0.0173, Val=0.0170
# [Ens 3] Epoch=42, Train=0.0172, Val=0.0171
# [Ens 3] Epoch=43, Train=0.0172, Val=0.0169
# [Ens 3] Epoch=44, Train=0.0171, Val=0.0167
# [Ens 3] Epoch=45, Train=0.0171, Val=0.0172
# [Ens 3] Epoch=46, Train=0.0171, Val=0.0165
# [Ens 3] Epoch=47, Train=0.0171, Val=0.0176
# [Ens 3] Epoch=48, Train=0.0170, Val=0.0165
# [Ens 3] Epoch=49, Train=0.0170, Val=0.0172
# [Ens 3] Epoch=50, Train=0.0170, Val=0.0166
# [Ens 3] Epoch=51, Train=0.0170, Val=0.0169
# [Ens 3] Epoch=52, Train=0.0169, Val=0.0179
# [Ens 3] Epoch=53, Train=0.0169, Val=0.0165
# [Ens 3] Epoch=54, Train=0.0169, Val=0.0174
# [Ens 3] Epoch=55, Train=0.0168, Val=0.0166
# [Ens 3] Epoch=56, Train=0.0168, Val=0.0170
# [Ens 3] Epoch=57, Train=0.0168, Val=0.0165
# [Ens 3] Epoch=58, Train=0.0167, Val=0.0164
# [Ens 3] Epoch=59, Train=0.0167, Val=0.0165
# [Ens 3] Epoch=60, Train=0.0166, Val=0.0162
# [Ens 3] Epoch=61, Train=0.0166, Val=0.0160
# [Ens 3] Epoch=62, Train=0.0166, Val=0.0165
# [Ens 3] Epoch=63, Train=0.0166, Val=0.0163
# [Ens 3] Epoch=64, Train=0.0164, Val=0.0161
# [Ens 3] Epoch=65, Train=0.0163, Val=0.0168
# [Ens 3] Epoch=66, Train=0.0162, Val=0.0166
# [Ens 3] Epoch=67, Train=0.0162, Val=0.0159
# [Ens 3] Epoch=68, Train=0.0161, Val=0.0157
# [Ens 3] Epoch=69, Train=0.0161, Val=0.0156
# [Ens 3] Epoch=70, Train=0.0160, Val=0.0158
# [Ens 3] Epoch=71, Train=0.0160, Val=0.0156
# [Ens 3] Epoch=72, Train=0.0160, Val=0.0157
# [Ens 3] Epoch=73, Train=0.0159, Val=0.0157
# [Ens 3] Epoch=74, Train=0.0159, Val=0.0164
# [Ens 3] Epoch=75, Train=0.0159, Val=0.0154
# [Ens 3] Epoch=76, Train=0.0158, Val=0.0156
# [Ens 3] Epoch=77, Train=0.0158, Val=0.0154
# [Ens 3] Epoch=78, Train=0.0157, Val=0.0152
# [Ens 3] Epoch=79, Train=0.0157, Val=0.0153
# [Ens 3] Epoch=80, Train=0.0156, Val=0.0154
# [Ens 3] Epoch=81, Train=0.0156, Val=0.0151
# [Ens 3] Epoch=82, Train=0.0156, Val=0.0154
# [Ens 3] Epoch=83, Train=0.0156, Val=0.0153
# [Ens 3] Epoch=84, Train=0.0155, Val=0.0151
# [Ens 3] Epoch=85, Train=0.0155, Val=0.0153
# [Ens 3] Epoch=86, Train=0.0155, Val=0.0151
# [Ens 3] Epoch=87, Train=0.0155, Val=0.0151
# [Ens 3] Epoch=88, Train=0.0154, Val=0.0155
# [Ens 3] Epoch=89, Train=0.0153, Val=0.0149
# [Ens 3] Epoch=90, Train=0.0152, Val=0.0146
# [Ens 3] Epoch=91, Train=0.0151, Val=0.0147
# [Ens 3] Epoch=92, Train=0.0150, Val=0.0146
# [Ens 3] Epoch=93, Train=0.0149, Val=0.0144
# [Ens 3] Epoch=94, Train=0.0148, Val=0.0141
# [Ens 3] Epoch=95, Train=0.0147, Val=0.0141
# [Ens 3] Epoch=96, Train=0.0146, Val=0.0143
# [Ens 3] Epoch=97, Train=0.0146, Val=0.0142
# [Ens 3] Epoch=98, Train=0.0146, Val=0.0143
# [Ens 3] Epoch=99, Train=0.0145, Val=0.0147
# [Ens 3] Epoch=100, Train=0.0145, Val=0.0153
# [Ens 3] Epoch=101, Train=0.0145, Val=0.0138
# [Ens 3] Epoch=102, Train=0.0144, Val=0.0140
# [Ens 3] Epoch=103, Train=0.0144, Val=0.0145
# [Ens 3] Epoch=104, Train=0.0144, Val=0.0138
# [Ens 3] Epoch=105, Train=0.0143, Val=0.0139
# [Ens 3] Epoch=106, Train=0.0143, Val=0.0139
# [Ens 3] Epoch=107, Train=0.0143, Val=0.0137
# [Ens 3] Epoch=108, Train=0.0142, Val=0.0140
# [Ens 3] Epoch=109, Train=0.0142, Val=0.0146
# [Ens 3] Epoch=110, Train=0.0142, Val=0.0140
# [Ens 3] Epoch=111, Train=0.0142, Val=0.0138
# [Ens 3] Epoch=112, Train=0.0141, Val=0.0136
# [Ens 3] Epoch=113, Train=0.0141, Val=0.0138
# [Ens 3] Epoch=114, Train=0.0141, Val=0.0135
# [Ens 3] Epoch=115, Train=0.0141, Val=0.0140
# [Ens 3] Epoch=116, Train=0.0140, Val=0.0142
# [Ens 3] Epoch=117, Train=0.0140, Val=0.0134
# [Ens 3] Epoch=118, Train=0.0140, Val=0.0137
# [Ens 3] Epoch=119, Train=0.0140, Val=0.0137
# [Ens 3] Epoch=120, Train=0.0140, Val=0.0136
# [Ens 3] Epoch=121, Train=0.0139, Val=0.0136
# [Ens 3] Epoch=122, Train=0.0139, Val=0.0136
# [Ens 3] Epoch=123, Train=0.0139, Val=0.0139
# [Ens 3] Epoch=124, Train=0.0139, Val=0.0136
# [Ens 3] Epoch=125, Train=0.0139, Val=0.0138
# [Ens 3] Epoch=126, Train=0.0138, Val=0.0134
# [Ens 3] Epoch=127, Train=0.0138, Val=0.0135
# [Ens 3] Epoch=128, Train=0.0138, Val=0.0135
# [Ens 3] Epoch=129, Train=0.0138, Val=0.0135
# [Ens 3] Epoch=130, Train=0.0138, Val=0.0133
# [Ens 3] Epoch=131, Train=0.0138, Val=0.0134
# [Ens 3] Epoch=132, Train=0.0138, Val=0.0133
# [Ens 3] Epoch=133, Train=0.0138, Val=0.0136
# [Ens 3] Epoch=134, Train=0.0137, Val=0.0132
# [Ens 3] Epoch=135, Train=0.0137, Val=0.0131
# [Ens 3] Epoch=136, Train=0.0137, Val=0.0131
# [Ens 3] Epoch=137, Train=0.0137, Val=0.0134
# [Ens 3] Epoch=138, Train=0.0137, Val=0.0135
# [Ens 3] Epoch=139, Train=0.0137, Val=0.0132
# [Ens 3] Epoch=140, Train=0.0137, Val=0.0134
# [Ens 3] Epoch=141, Train=0.0137, Val=0.0132
# [Ens 3] Epoch=142, Train=0.0136, Val=0.0134
# [Ens 3] Epoch=143, Train=0.0136, Val=0.0132
# [Ens 3] Epoch=144, Train=0.0136, Val=0.0131
# [Ens 3] Epoch=145, Train=0.0136, Val=0.0133
# [Ens 3] Epoch=146, Train=0.0136, Val=0.0134
# [Ens 3] Epoch=147, Train=0.0136, Val=0.0131
# [Ens 3] Epoch=148, Train=0.0136, Val=0.0132
# [Ens 3] Epoch=149, Train=0.0135, Val=0.0133
# [Ens 3] Epoch=150, Train=0.0135, Val=0.0130
# [Ens 3] Epoch=151, Train=0.0135, Val=0.0131
# [Ens 3] Epoch=152, Train=0.0135, Val=0.0131
# [Ens 3] Epoch=153, Train=0.0135, Val=0.0131
# [Ens 3] Epoch=154, Train=0.0135, Val=0.0131
# [Ens 3] Epoch=155, Train=0.0135, Val=0.0129
# [Ens 3] Epoch=156, Train=0.0134, Val=0.0132
# [Ens 3] Epoch=157, Train=0.0134, Val=0.0131
# [Ens 3] Epoch=158, Train=0.0134, Val=0.0130
# [Ens 3] Epoch=159, Train=0.0134, Val=0.0129
# [Ens 3] Epoch=160, Train=0.0134, Val=0.0129
# [Ens 3] Epoch=161, Train=0.0134, Val=0.0132
# [Ens 3] Epoch=162, Train=0.0134, Val=0.0128
# [Ens 3] Epoch=163, Train=0.0134, Val=0.0129
# [Ens 3] Epoch=164, Train=0.0134, Val=0.0128
# [Ens 3] Epoch=165, Train=0.0134, Val=0.0129
# [Ens 3] Epoch=166, Train=0.0134, Val=0.0132
# [Ens 3] Epoch=167, Train=0.0133, Val=0.0129
# [Ens 3] Epoch=168, Train=0.0133, Val=0.0128
# [Ens 3] Epoch=169, Train=0.0133, Val=0.0129
# [Ens 3] Epoch=170, Train=0.0133, Val=0.0128
# [Ens 3] Epoch=171, Train=0.0133, Val=0.0128
# [Ens 3] Epoch=172, Train=0.0133, Val=0.0128
# [Ens 3] Epoch=173, Train=0.0133, Val=0.0128
# [Ens 3] Epoch=174, Train=0.0133, Val=0.0130
# [Ens 3] Epoch=175, Train=0.0133, Val=0.0128
# [Ens 3] Epoch=176, Train=0.0133, Val=0.0129
# [Ens 3] Epoch=177, Train=0.0133, Val=0.0128
# [Ens 3] Epoch=178, Train=0.0132, Val=0.0129
# [Ens 3] Epoch=179, Train=0.0132, Val=0.0128
# [Ens 3] Epoch=180, Train=0.0132, Val=0.0128
# [Ens 3] Epoch=181, Train=0.0132, Val=0.0129
# [Ens 3] Epoch=182, Train=0.0132, Val=0.0128
# [Ens 3] Epoch=183, Train=0.0132, Val=0.0127
# [Ens 3] Epoch=184, Train=0.0132, Val=0.0128
# [Ens 3] Epoch=185, Train=0.0132, Val=0.0127
# [Ens 3] Epoch=186, Train=0.0132, Val=0.0127
# [Ens 3] Epoch=187, Train=0.0132, Val=0.0127
# [Ens 3] Epoch=188, Train=0.0132, Val=0.0128
# [Ens 3] Epoch=189, Train=0.0132, Val=0.0127
# [Ens 3] Epoch=190, Train=0.0132, Val=0.0127
# [Ens 3] Epoch=191, Train=0.0132, Val=0.0127
# [Ens 3] Epoch=192, Train=0.0132, Val=0.0128
# [Ens 3] Epoch=193, Train=0.0132, Val=0.0131
# [Ens 3] Epoch=194, Train=0.0132, Val=0.0127
# [Ens 3] Epoch=195, Train=0.0132, Val=0.0128
# [Ens 3] Epoch=196, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=197, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=198, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=199, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=200, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=201, Train=0.0131, Val=0.0126
# [Ens 3] Epoch=202, Train=0.0131, Val=0.0126
# [Ens 3] Epoch=203, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=204, Train=0.0131, Val=0.0126
# [Ens 3] Epoch=205, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=206, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=207, Train=0.0131, Val=0.0126
# [Ens 3] Epoch=208, Train=0.0131, Val=0.0126
# [Ens 3] Epoch=209, Train=0.0131, Val=0.0126
# [Ens 3] Epoch=210, Train=0.0131, Val=0.0126
# [Ens 3] Epoch=211, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=212, Train=0.0131, Val=0.0126
# [Ens 3] Epoch=213, Train=0.0131, Val=0.0127
# [Ens 3] Epoch=214, Train=0.0130, Val=0.0127
# [Ens 3] Epoch=215, Train=0.0130, Val=0.0126
# [Ens 3] Epoch=216, Train=0.0130, Val=0.0126
# [Ens 3] Epoch=217, Train=0.0130, Val=0.0126
# [Ens 3] Epoch=218, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=219, Train=0.0130, Val=0.0126
# [Ens 3] Epoch=220, Train=0.0130, Val=0.0126
# [Ens 3] Epoch=221, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=222, Train=0.0130, Val=0.0126
# [Ens 3] Epoch=223, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=224, Train=0.0130, Val=0.0126
# [Ens 3] Epoch=225, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=226, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=227, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=228, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=229, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=230, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=231, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=232, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=233, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=234, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=235, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=236, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=237, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=238, Train=0.0130, Val=0.0125
# [Ens 3] Epoch=239, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=240, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=241, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=242, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=243, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=244, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=245, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=246, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=247, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=248, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=249, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=250, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=251, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=252, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=253, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=254, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=255, Train=0.0129, Val=0.0125
# [Ens 3] Epoch=256, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=257, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=258, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=259, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=260, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=261, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=262, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=263, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=264, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=265, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=266, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=267, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=268, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=269, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=270, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=271, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=272, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=273, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=274, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=275, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=276, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=277, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=278, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=279, Train=0.0129, Val=0.0124
# [Ens 3] Epoch=280, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=281, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=282, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=283, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=284, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=285, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=286, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=287, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=288, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=289, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=290, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=291, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=292, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=293, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=294, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=295, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=296, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=297, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=298, Train=0.0128, Val=0.0124
# [Ens 3] Epoch=299, Train=0.0128, Val=0.0124
# ✅ Saved partial ensemble: TiDE_params_ensemble_partial_3.pkl
#
# ====== Ensemble model 4/7 | seed=203 ======
# [Ens 4] Epoch=0, Train=0.0432, Val=0.0214
# [Ens 4] Epoch=1, Train=0.0211, Val=0.0200
# [Ens 4] Epoch=2, Train=0.0202, Val=0.0199
# [Ens 4] Epoch=3, Train=0.0197, Val=0.0202
# [Ens 4] Epoch=4, Train=0.0193, Val=0.0184
# [Ens 4] Epoch=5, Train=0.0191, Val=0.0194
# [Ens 4] Epoch=6, Train=0.0188, Val=0.0187
# [Ens 4] Epoch=7, Train=0.0188, Val=0.0192
# [Ens 4] Epoch=8, Train=0.0187, Val=0.0211
# [Ens 4] Epoch=9, Train=0.0186, Val=0.0196
# [Ens 4] Epoch=10, Train=0.0184, Val=0.0207
# [Ens 4] Epoch=11, Train=0.0182, Val=0.0184
# [Ens 4] Epoch=12, Train=0.0181, Val=0.0175
# [Ens 4] Epoch=13, Train=0.0180, Val=0.0185
# [Ens 4] Epoch=14, Train=0.0178, Val=0.0183
# [Ens 4] Epoch=15, Train=0.0178, Val=0.0172
# [Ens 4] Epoch=16, Train=0.0177, Val=0.0195
# [Ens 4] Epoch=17, Train=0.0177, Val=0.0180
# [Ens 4] Epoch=18, Train=0.0176, Val=0.0168
# [Ens 4] Epoch=19, Train=0.0176, Val=0.0199
# [Ens 4] Epoch=20, Train=0.0175, Val=0.0189
# [Ens 4] Epoch=21, Train=0.0175, Val=0.0173
# [Ens 4] Epoch=22, Train=0.0174, Val=0.0173
# [Ens 4] Epoch=23, Train=0.0174, Val=0.0170
# [Ens 4] Epoch=24, Train=0.0173, Val=0.0167
# [Ens 4] Epoch=25, Train=0.0173, Val=0.0172
# [Ens 4] Epoch=26, Train=0.0172, Val=0.0177
# [Ens 4] Epoch=27, Train=0.0172, Val=0.0171
# [Ens 4] Epoch=28, Train=0.0171, Val=0.0166
# [Ens 4] Epoch=29, Train=0.0171, Val=0.0167
# [Ens 4] Epoch=30, Train=0.0171, Val=0.0166
# [Ens 4] Epoch=31, Train=0.0171, Val=0.0173
# [Ens 4] Epoch=32, Train=0.0170, Val=0.0185
# [Ens 4] Epoch=33, Train=0.0170, Val=0.0172
# [Ens 4] Epoch=34, Train=0.0170, Val=0.0170
# [Ens 4] Epoch=35, Train=0.0169, Val=0.0167
# [Ens 4] Epoch=36, Train=0.0169, Val=0.0167
# [Ens 4] Epoch=37, Train=0.0169, Val=0.0169
# [Ens 4] Epoch=38, Train=0.0168, Val=0.0168
# [Ens 4] Epoch=39, Train=0.0169, Val=0.0182
# [Ens 4] Epoch=40, Train=0.0168, Val=0.0179
# [Ens 4] Epoch=41, Train=0.0168, Val=0.0169
# [Ens 4] Epoch=42, Train=0.0168, Val=0.0163
# [Ens 4] Epoch=43, Train=0.0168, Val=0.0178
# [Ens 4] Epoch=44, Train=0.0167, Val=0.0165
# [Ens 4] Epoch=45, Train=0.0167, Val=0.0166
# [Ens 4] Epoch=46, Train=0.0167, Val=0.0162
# [Ens 4] Epoch=47, Train=0.0167, Val=0.0161
# [Ens 4] Epoch=48, Train=0.0166, Val=0.0165
# [Ens 4] Epoch=49, Train=0.0166, Val=0.0167
# [Ens 4] Epoch=50, Train=0.0166, Val=0.0169
# [Ens 4] Epoch=51, Train=0.0166, Val=0.0171
# [Ens 4] Epoch=52, Train=0.0165, Val=0.0176
# [Ens 4] Epoch=53, Train=0.0166, Val=0.0163
# [Ens 4] Epoch=54, Train=0.0165, Val=0.0167
# [Ens 4] Epoch=55, Train=0.0165, Val=0.0163
# [Ens 4] Epoch=56, Train=0.0165, Val=0.0161
# [Ens 4] Epoch=57, Train=0.0165, Val=0.0164
# [Ens 4] Epoch=58, Train=0.0164, Val=0.0164
# [Ens 4] Epoch=59, Train=0.0164, Val=0.0161
# [Ens 4] Epoch=60, Train=0.0164, Val=0.0165
# [Ens 4] Epoch=61, Train=0.0164, Val=0.0161
# [Ens 4] Epoch=62, Train=0.0163, Val=0.0164
# [Ens 4] Epoch=63, Train=0.0163, Val=0.0160
# [Ens 4] Epoch=64, Train=0.0163, Val=0.0171
# [Ens 4] Epoch=65, Train=0.0163, Val=0.0162
# [Ens 4] Epoch=66, Train=0.0163, Val=0.0159
# [Ens 4] Epoch=67, Train=0.0163, Val=0.0159
# [Ens 4] Epoch=68, Train=0.0162, Val=0.0176
# [Ens 4] Epoch=69, Train=0.0162, Val=0.0159
# [Ens 4] Epoch=70, Train=0.0162, Val=0.0161
# [Ens 4] Epoch=71, Train=0.0162, Val=0.0166
# [Ens 4] Epoch=72, Train=0.0162, Val=0.0160
# [Ens 4] Epoch=73, Train=0.0162, Val=0.0162
# [Ens 4] Epoch=74, Train=0.0161, Val=0.0157
# [Ens 4] Epoch=75, Train=0.0161, Val=0.0160
# [Ens 4] Epoch=76, Train=0.0161, Val=0.0160
# [Ens 4] Epoch=77, Train=0.0161, Val=0.0158
# [Ens 4] Epoch=78, Train=0.0160, Val=0.0156
# [Ens 4] Epoch=79, Train=0.0161, Val=0.0159
# [Ens 4] Epoch=80, Train=0.0160, Val=0.0156
# [Ens 4] Epoch=81, Train=0.0160, Val=0.0161
# [Ens 4] Epoch=82, Train=0.0160, Val=0.0155
# [Ens 4] Epoch=83, Train=0.0160, Val=0.0156
# [Ens 4] Epoch=84, Train=0.0160, Val=0.0157
# [Ens 4] Epoch=85, Train=0.0159, Val=0.0156
# [Ens 4] Epoch=86, Train=0.0159, Val=0.0164
# [Ens 4] Epoch=87, Train=0.0159, Val=0.0161
# [Ens 4] Epoch=88, Train=0.0156, Val=0.0152
# [Ens 4] Epoch=89, Train=0.0154, Val=0.0156
# [Ens 4] Epoch=90, Train=0.0154, Val=0.0151
# [Ens 4] Epoch=91, Train=0.0154, Val=0.0151
# [Ens 4] Epoch=92, Train=0.0153, Val=0.0149
# [Ens 4] Epoch=93, Train=0.0153, Val=0.0149
# [Ens 4] Epoch=94, Train=0.0152, Val=0.0154
# [Ens 4] Epoch=95, Train=0.0152, Val=0.0148
# [Ens 4] Epoch=96, Train=0.0152, Val=0.0152
# [Ens 4] Epoch=97, Train=0.0152, Val=0.0147
# [Ens 4] Epoch=98, Train=0.0151, Val=0.0152
# [Ens 4] Epoch=99, Train=0.0151, Val=0.0147
# [Ens 4] Epoch=100, Train=0.0150, Val=0.0146
# [Ens 4] Epoch=101, Train=0.0150, Val=0.0146
# [Ens 4] Epoch=102, Train=0.0149, Val=0.0144
# [Ens 4] Epoch=103, Train=0.0148, Val=0.0143
# [Ens 4] Epoch=104, Train=0.0147, Val=0.0144
# [Ens 4] Epoch=105, Train=0.0147, Val=0.0146
# [Ens 4] Epoch=106, Train=0.0146, Val=0.0143
# [Ens 4] Epoch=107, Train=0.0145, Val=0.0145
# [Ens 4] Epoch=108, Train=0.0144, Val=0.0141
# [Ens 4] Epoch=109, Train=0.0144, Val=0.0137
# [Ens 4] Epoch=110, Train=0.0143, Val=0.0138
# [Ens 4] Epoch=111, Train=0.0142, Val=0.0140
# [Ens 4] Epoch=112, Train=0.0142, Val=0.0145
# [Ens 4] Epoch=113, Train=0.0141, Val=0.0139
# [Ens 4] Epoch=114, Train=0.0141, Val=0.0137
# [Ens 4] Epoch=115, Train=0.0140, Val=0.0138
# [Ens 4] Epoch=116, Train=0.0140, Val=0.0136
# [Ens 4] Epoch=117, Train=0.0140, Val=0.0134
# [Ens 4] Epoch=118, Train=0.0139, Val=0.0136
# [Ens 4] Epoch=119, Train=0.0139, Val=0.0135
# [Ens 4] Epoch=120, Train=0.0139, Val=0.0139
# [Ens 4] Epoch=121, Train=0.0139, Val=0.0137
# [Ens 4] Epoch=122, Train=0.0138, Val=0.0134
# [Ens 4] Epoch=123, Train=0.0138, Val=0.0135
# [Ens 4] Epoch=124, Train=0.0138, Val=0.0133
# [Ens 4] Epoch=125, Train=0.0138, Val=0.0143
# [Ens 4] Epoch=126, Train=0.0137, Val=0.0133
# [Ens 4] Epoch=127, Train=0.0137, Val=0.0133
# [Ens 4] Epoch=128, Train=0.0137, Val=0.0133
# [Ens 4] Epoch=129, Train=0.0137, Val=0.0134
# [Ens 4] Epoch=130, Train=0.0136, Val=0.0131
# [Ens 4] Epoch=131, Train=0.0137, Val=0.0134
# [Ens 4] Epoch=132, Train=0.0136, Val=0.0133
# [Ens 4] Epoch=133, Train=0.0136, Val=0.0133
# [Ens 4] Epoch=134, Train=0.0136, Val=0.0135
# [Ens 4] Epoch=135, Train=0.0136, Val=0.0132
# [Ens 4] Epoch=136, Train=0.0135, Val=0.0132
# [Ens 4] Epoch=137, Train=0.0135, Val=0.0131
# [Ens 4] Epoch=138, Train=0.0135, Val=0.0135
# [Ens 4] Epoch=139, Train=0.0135, Val=0.0134
# [Ens 4] Epoch=140, Train=0.0134, Val=0.0130
# [Ens 4] Epoch=141, Train=0.0134, Val=0.0130
# [Ens 4] Epoch=142, Train=0.0134, Val=0.0130
# [Ens 4] Epoch=143, Train=0.0134, Val=0.0130
# [Ens 4] Epoch=144, Train=0.0134, Val=0.0131
# [Ens 4] Epoch=145, Train=0.0134, Val=0.0131
# [Ens 4] Epoch=146, Train=0.0133, Val=0.0128
# [Ens 4] Epoch=147, Train=0.0133, Val=0.0129
# [Ens 4] Epoch=148, Train=0.0132, Val=0.0130
# [Ens 4] Epoch=149, Train=0.0132, Val=0.0130
# [Ens 4] Epoch=150, Train=0.0132, Val=0.0127
# [Ens 4] Epoch=151, Train=0.0131, Val=0.0127
# [Ens 4] Epoch=152, Train=0.0131, Val=0.0128
# [Ens 4] Epoch=153, Train=0.0131, Val=0.0127
# [Ens 4] Epoch=154, Train=0.0131, Val=0.0125
# [Ens 4] Epoch=155, Train=0.0130, Val=0.0126
# [Ens 4] Epoch=156, Train=0.0130, Val=0.0125
# [Ens 4] Epoch=157, Train=0.0130, Val=0.0126
# [Ens 4] Epoch=158, Train=0.0130, Val=0.0125
# [Ens 4] Epoch=159, Train=0.0130, Val=0.0125
# [Ens 4] Epoch=160, Train=0.0129, Val=0.0124
# [Ens 4] Epoch=161, Train=0.0129, Val=0.0126
# [Ens 4] Epoch=162, Train=0.0129, Val=0.0126
# [Ens 4] Epoch=163, Train=0.0129, Val=0.0125
# [Ens 4] Epoch=164, Train=0.0129, Val=0.0124
# [Ens 4] Epoch=165, Train=0.0129, Val=0.0126
# [Ens 4] Epoch=166, Train=0.0129, Val=0.0125
# [Ens 4] Epoch=167, Train=0.0129, Val=0.0124
# [Ens 4] Epoch=168, Train=0.0128, Val=0.0126
# [Ens 4] Epoch=169, Train=0.0128, Val=0.0127
# [Ens 4] Epoch=170, Train=0.0128, Val=0.0123
# [Ens 4] Epoch=171, Train=0.0128, Val=0.0124
# [Ens 4] Epoch=172, Train=0.0128, Val=0.0124
# [Ens 4] Epoch=173, Train=0.0128, Val=0.0124
# [Ens 4] Epoch=174, Train=0.0128, Val=0.0124
# [Ens 4] Epoch=175, Train=0.0128, Val=0.0123
# [Ens 4] Epoch=176, Train=0.0128, Val=0.0123
# [Ens 4] Epoch=177, Train=0.0128, Val=0.0123
# [Ens 4] Epoch=178, Train=0.0127, Val=0.0124
# [Ens 4] Epoch=179, Train=0.0127, Val=0.0123
# [Ens 4] Epoch=180, Train=0.0127, Val=0.0122
# [Ens 4] Epoch=181, Train=0.0127, Val=0.0122
# [Ens 4] Epoch=182, Train=0.0127, Val=0.0122
# [Ens 4] Epoch=183, Train=0.0127, Val=0.0123
# [Ens 4] Epoch=184, Train=0.0127, Val=0.0122
# [Ens 4] Epoch=185, Train=0.0127, Val=0.0123
# [Ens 4] Epoch=186, Train=0.0127, Val=0.0122
# [Ens 4] Epoch=187, Train=0.0127, Val=0.0123
# [Ens 4] Epoch=188, Train=0.0127, Val=0.0123
# [Ens 4] Epoch=189, Train=0.0127, Val=0.0122
# [Ens 4] Epoch=190, Train=0.0127, Val=0.0121
# [Ens 4] Epoch=191, Train=0.0127, Val=0.0122
# ...
# [Ens 6] Epoch=238, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=239, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=240, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=241, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=242, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=243, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=244, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=245, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=246, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=247, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=248, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=249, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=250, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=251, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=252, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=253, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=254, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=255, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=256, Train=0.0120, Val=0.0116
# [Ens 6] Epoch=257, Train=0.0120, Val=0.0117
# [Ens 6] Epoch=258, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=259, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=260, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=261, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=262, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=263, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=264, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=265, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=266, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=267, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=268, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=269, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=270, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=271, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=272, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=273, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=274, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=275, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=276, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=277, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=278, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=279, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=280, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=281, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=282, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=283, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=284, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=285, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=286, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=287, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=288, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=289, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=290, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=291, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=292, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=293, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=294, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=295, Train=0.0119, Val=0.0115
# [Ens 6] Epoch=296, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=297, Train=0.0119, Val=0.0116
# [Ens 6] Epoch=298, Train=0.0119, Val=0.0115
# [Ens 6] Epoch=299, Train=0.0119, Val=0.0116
# ✅ Saved partial ensemble: TiDE_params_ensemble_partial_6.pkl
#
# ====== Ensemble model 7/7 | seed=206 ======
# [Ens 7] Epoch=0, Train=0.0432, Val=0.0240
# [Ens 7] Epoch=1, Train=0.0219, Val=0.0206
# [Ens 7] Epoch=2, Train=0.0202, Val=0.0190
# [Ens 7] Epoch=3, Train=0.0196, Val=0.0195
# [Ens 7] Epoch=4, Train=0.0193, Val=0.0193
# [Ens 7] Epoch=5, Train=0.0191, Val=0.0188
# [Ens 7] Epoch=6, Train=0.0188, Val=0.0178
# [Ens 7] Epoch=7, Train=0.0187, Val=0.0208
# [Ens 7] Epoch=8, Train=0.0186, Val=0.0194
# [Ens 7] Epoch=9, Train=0.0185, Val=0.0177
# [Ens 7] Epoch=10, Train=0.0184, Val=0.0191
# [Ens 7] Epoch=11, Train=0.0184, Val=0.0191
# [Ens 7] Epoch=12, Train=0.0183, Val=0.0184
# [Ens 7] Epoch=13, Train=0.0183, Val=0.0198
# [Ens 7] Epoch=14, Train=0.0183, Val=0.0192
# [Ens 7] Epoch=15, Train=0.0183, Val=0.0178
# [Ens 7] Epoch=16, Train=0.0182, Val=0.0186
# [Ens 7] Epoch=17, Train=0.0182, Val=0.0178
# [Ens 7] Epoch=18, Train=0.0181, Val=0.0178
# [Ens 7] Epoch=19, Train=0.0181, Val=0.0203
# [Ens 7] Epoch=20, Train=0.0180, Val=0.0174
# [Ens 7] Epoch=21, Train=0.0180, Val=0.0177
# [Ens 7] Epoch=22, Train=0.0179, Val=0.0181
# [Ens 7] Epoch=23, Train=0.0180, Val=0.0175
# [Ens 7] Epoch=24, Train=0.0179, Val=0.0187
# [Ens 7] Epoch=25, Train=0.0179, Val=0.0177
# [Ens 7] Epoch=26, Train=0.0178, Val=0.0185
# [Ens 7] Epoch=27, Train=0.0178, Val=0.0176
# [Ens 7] Epoch=28, Train=0.0178, Val=0.0176
# [Ens 7] Epoch=29, Train=0.0178, Val=0.0187
# [Ens 7] Epoch=30, Train=0.0177, Val=0.0174
# [Ens 7] Epoch=31, Train=0.0177, Val=0.0177
# [Ens 7] Epoch=32, Train=0.0177, Val=0.0173
# [Ens 7] Epoch=33, Train=0.0177, Val=0.0182
# [Ens 7] Epoch=34, Train=0.0176, Val=0.0173
# [Ens 7] Epoch=35, Train=0.0176, Val=0.0179
# [Ens 7] Epoch=36, Train=0.0176, Val=0.0172
# [Ens 7] Epoch=37, Train=0.0176, Val=0.0176
# [Ens 7] Epoch=38, Train=0.0175, Val=0.0170
# [Ens 7] Epoch=39, Train=0.0175, Val=0.0171
# [Ens 7] Epoch=40, Train=0.0175, Val=0.0169
# [Ens 7] Epoch=41, Train=0.0174, Val=0.0177
# [Ens 7] Epoch=42, Train=0.0174, Val=0.0173
# [Ens 7] Epoch=43, Train=0.0174, Val=0.0170
# [Ens 7] Epoch=44, Train=0.0174, Val=0.0171
# [Ens 7] Epoch=45, Train=0.0173, Val=0.0172
# [Ens 7] Epoch=46, Train=0.0173, Val=0.0171
# [Ens 7] Epoch=47, Train=0.0173, Val=0.0172
# [Ens 7] Epoch=48, Train=0.0173, Val=0.0174
# [Ens 7] Epoch=49, Train=0.0172, Val=0.0169
# [Ens 7] Epoch=50, Train=0.0172, Val=0.0173
# [Ens 7] Epoch=51, Train=0.0172, Val=0.0179
# [Ens 7] Epoch=52, Train=0.0172, Val=0.0168
# [Ens 7] Epoch=53, Train=0.0172, Val=0.0172
# [Ens 7] Epoch=54, Train=0.0171, Val=0.0174
# [Ens 7] Epoch=55, Train=0.0171, Val=0.0171
# [Ens 7] Epoch=56, Train=0.0171, Val=0.0170
# [Ens 7] Epoch=57, Train=0.0171, Val=0.0175
# [Ens 7] Epoch=58, Train=0.0171, Val=0.0168
# [Ens 7] Epoch=59, Train=0.0170, Val=0.0170
# [Ens 7] Epoch=60, Train=0.0170, Val=0.0172
# [Ens 7] Epoch=61, Train=0.0170, Val=0.0167
# [Ens 7] Epoch=62, Train=0.0170, Val=0.0171
# [Ens 7] Epoch=63, Train=0.0170, Val=0.0168
# [Ens 7] Epoch=64, Train=0.0169, Val=0.0168
# [Ens 7] Epoch=65, Train=0.0169, Val=0.0168
# [Ens 7] Epoch=66, Train=0.0169, Val=0.0169
# [Ens 7] Epoch=67, Train=0.0169, Val=0.0168
# [Ens 7] Epoch=68, Train=0.0168, Val=0.0165
# [Ens 7] Epoch=69, Train=0.0168, Val=0.0173
# [Ens 7] Epoch=70, Train=0.0168, Val=0.0167
# [Ens 7] Epoch=71, Train=0.0168, Val=0.0171
# [Ens 7] Epoch=72, Train=0.0167, Val=0.0169
# [Ens 7] Epoch=73, Train=0.0167, Val=0.0164
# [Ens 7] Epoch=74, Train=0.0167, Val=0.0162
# [Ens 7] Epoch=75, Train=0.0166, Val=0.0166
# [Ens 7] Epoch=76, Train=0.0166, Val=0.0181
# [Ens 7] Epoch=77, Train=0.0166, Val=0.0164
# [Ens 7] Epoch=78, Train=0.0165, Val=0.0161
# [Ens 7] Epoch=79, Train=0.0165, Val=0.0164
# [Ens 7] Epoch=80, Train=0.0165, Val=0.0166
# [Ens 7] Epoch=81, Train=0.0165, Val=0.0164
# [Ens 7] Epoch=82, Train=0.0165, Val=0.0166
# [Ens 7] Epoch=83, Train=0.0164, Val=0.0165
# [Ens 7] Epoch=84, Train=0.0164, Val=0.0161
# [Ens 7] Epoch=85, Train=0.0164, Val=0.0162
# [Ens 7] Epoch=86, Train=0.0163, Val=0.0161
# [Ens 7] Epoch=87, Train=0.0163, Val=0.0177
# [Ens 7] Epoch=88, Train=0.0163, Val=0.0161
# [Ens 7] Epoch=89, Train=0.0163, Val=0.0160
# [Ens 7] Epoch=90, Train=0.0163, Val=0.0161
# [Ens 7] Epoch=91, Train=0.0162, Val=0.0159
# [Ens 7] Epoch=92, Train=0.0162, Val=0.0160
# [Ens 7] Epoch=93, Train=0.0162, Val=0.0158
# [Ens 7] Epoch=94, Train=0.0162, Val=0.0157
# [Ens 7] Epoch=95, Train=0.0162, Val=0.0163
# [Ens 7] Epoch=96, Train=0.0161, Val=0.0158
# [Ens 7] Epoch=97, Train=0.0161, Val=0.0162
# [Ens 7] Epoch=98, Train=0.0161, Val=0.0159
# [Ens 7] Epoch=99, Train=0.0161, Val=0.0161
# [Ens 7] Epoch=100, Train=0.0160, Val=0.0158
# [Ens 7] Epoch=101, Train=0.0159, Val=0.0160
# [Ens 7] Epoch=102, Train=0.0158, Val=0.0155
# [Ens 7] Epoch=103, Train=0.0157, Val=0.0154
# [Ens 7] Epoch=104, Train=0.0156, Val=0.0156
# [Ens 7] Epoch=105, Train=0.0156, Val=0.0154
# [Ens 7] Epoch=106, Train=0.0155, Val=0.0154
# [Ens 7] Epoch=107, Train=0.0155, Val=0.0154
# [Ens 7] Epoch=108, Train=0.0154, Val=0.0155
# [Ens 7] Epoch=109, Train=0.0154, Val=0.0152
# [Ens 7] Epoch=110, Train=0.0154, Val=0.0150
# [Ens 7] Epoch=111, Train=0.0153, Val=0.0149
# [Ens 7] Epoch=112, Train=0.0153, Val=0.0150
# [Ens 7] Epoch=113, Train=0.0152, Val=0.0152
# [Ens 7] Epoch=114, Train=0.0152, Val=0.0149
# [Ens 7] Epoch=115, Train=0.0151, Val=0.0153
# [Ens 7] Epoch=116, Train=0.0150, Val=0.0148
# [Ens 7] Epoch=117, Train=0.0150, Val=0.0150
# [Ens 7] Epoch=118, Train=0.0149, Val=0.0151
# [Ens 7] Epoch=119, Train=0.0149, Val=0.0145
# [Ens 7] Epoch=120, Train=0.0149, Val=0.0145
# [Ens 7] Epoch=121, Train=0.0148, Val=0.0149
# [Ens 7] Epoch=122, Train=0.0148, Val=0.0144
# [Ens 7] Epoch=123, Train=0.0148, Val=0.0145
# [Ens 7] Epoch=124, Train=0.0148, Val=0.0144
# [Ens 7] Epoch=125, Train=0.0148, Val=0.0143
# [Ens 7] Epoch=126, Train=0.0147, Val=0.0147
# [Ens 7] Epoch=127, Train=0.0147, Val=0.0146
# [Ens 7] Epoch=128, Train=0.0147, Val=0.0144
# [Ens 7] Epoch=129, Train=0.0147, Val=0.0141
# [Ens 7] Epoch=130, Train=0.0146, Val=0.0142
# [Ens 7] Epoch=131, Train=0.0146, Val=0.0145
# [Ens 7] Epoch=132, Train=0.0146, Val=0.0142
# [Ens 7] Epoch=133, Train=0.0146, Val=0.0142
# [Ens 7] Epoch=134, Train=0.0145, Val=0.0143
# [Ens 7] Epoch=135, Train=0.0145, Val=0.0142
# [Ens 7] Epoch=136, Train=0.0145, Val=0.0141
# [Ens 7] Epoch=137, Train=0.0145, Val=0.0141
# [Ens 7] Epoch=138, Train=0.0145, Val=0.0141
# [Ens 7] Epoch=139, Train=0.0145, Val=0.0142
# [Ens 7] Epoch=140, Train=0.0144, Val=0.0141
# [Ens 7] Epoch=141, Train=0.0144, Val=0.0140
# [Ens 7] Epoch=142, Train=0.0144, Val=0.0142
# [Ens 7] Epoch=143, Train=0.0144, Val=0.0144
# [Ens 7] Epoch=144, Train=0.0144, Val=0.0140
# [Ens 7] Epoch=145, Train=0.0144, Val=0.0142
# [Ens 7] Epoch=146, Train=0.0143, Val=0.0139
# [Ens 7] Epoch=147, Train=0.0143, Val=0.0138
# [Ens 7] Epoch=148, Train=0.0143, Val=0.0139
# [Ens 7] Epoch=149, Train=0.0143, Val=0.0142
# [Ens 7] Epoch=150, Train=0.0143, Val=0.0142
# [Ens 7] Epoch=151, Train=0.0143, Val=0.0140
# [Ens 7] Epoch=152, Train=0.0143, Val=0.0139
# [Ens 7] Epoch=153, Train=0.0143, Val=0.0139
# [Ens 7] Epoch=154, Train=0.0143, Val=0.0142
# [Ens 7] Epoch=155, Train=0.0142, Val=0.0139
# [Ens 7] Epoch=156, Train=0.0142, Val=0.0139
# [Ens 7] Epoch=157, Train=0.0142, Val=0.0140
# [Ens 7] Epoch=158, Train=0.0142, Val=0.0138
# [Ens 7] Epoch=159, Train=0.0142, Val=0.0140
# [Ens 7] Epoch=160, Train=0.0142, Val=0.0140
# [Ens 7] Epoch=161, Train=0.0142, Val=0.0138
# [Ens 7] Epoch=162, Train=0.0142, Val=0.0144
# [Ens 7] Epoch=163, Train=0.0142, Val=0.0138
# [Ens 7] Epoch=164, Train=0.0141, Val=0.0138
# [Ens 7] Epoch=165, Train=0.0141, Val=0.0137
# [Ens 7] Epoch=166, Train=0.0141, Val=0.0137
# [Ens 7] Epoch=167, Train=0.0141, Val=0.0137
# [Ens 7] Epoch=168, Train=0.0141, Val=0.0139
# [Ens 7] Epoch=169, Train=0.0141, Val=0.0137
# [Ens 7] Epoch=170, Train=0.0141, Val=0.0141
# [Ens 7] Epoch=171, Train=0.0140, Val=0.0136
# [Ens 7] Epoch=172, Train=0.0140, Val=0.0136
# [Ens 7] Epoch=173, Train=0.0140, Val=0.0136
# [Ens 7] Epoch=174, Train=0.0139, Val=0.0136
# [Ens 7] Epoch=175, Train=0.0139, Val=0.0135
# [Ens 7] Epoch=176, Train=0.0139, Val=0.0137
# [Ens 7] Epoch=177, Train=0.0139, Val=0.0136
# [Ens 7] Epoch=178, Train=0.0139, Val=0.0136
# [Ens 7] Epoch=179, Train=0.0139, Val=0.0135
# [Ens 7] Epoch=180, Train=0.0138, Val=0.0135
# [Ens 7] Epoch=181, Train=0.0138, Val=0.0135
# [Ens 7] Epoch=182, Train=0.0138, Val=0.0137
# [Ens 7] Epoch=183, Train=0.0138, Val=0.0136
# [Ens 7] Epoch=184, Train=0.0138, Val=0.0135
# [Ens 7] Epoch=185, Train=0.0138, Val=0.0134
# [Ens 7] Epoch=186, Train=0.0138, Val=0.0134
# [Ens 7] Epoch=187, Train=0.0138, Val=0.0135
# [Ens 7] Epoch=188, Train=0.0138, Val=0.0135
# [Ens 7] Epoch=189, Train=0.0138, Val=0.0135
# [Ens 7] Epoch=190, Train=0.0138, Val=0.0134
# [Ens 7] Epoch=191, Train=0.0138, Val=0.0135
# [Ens 7] Epoch=192, Train=0.0137, Val=0.0135
# [Ens 7] Epoch=193, Train=0.0137, Val=0.0134
# [Ens 7] Epoch=194, Train=0.0137, Val=0.0134
# [Ens 7] Epoch=195, Train=0.0137, Val=0.0134
# [Ens 7] Epoch=196, Train=0.0137, Val=0.0133
# [Ens 7] Epoch=197, Train=0.0137, Val=0.0133
# [Ens 7] Epoch=198, Train=0.0137, Val=0.0133
# [Ens 7] Epoch=199, Train=0.0136, Val=0.0132
# [Ens 7] Epoch=200, Train=0.0136, Val=0.0133
# [Ens 7] Epoch=201, Train=0.0136, Val=0.0133
# [Ens 7] Epoch=202, Train=0.0136, Val=0.0133
# [Ens 7] Epoch=203, Train=0.0136, Val=0.0132
# [Ens 7] Epoch=204, Train=0.0136, Val=0.0132
# [Ens 7] Epoch=205, Train=0.0136, Val=0.0133
# [Ens 7] Epoch=206, Train=0.0136, Val=0.0132
# [Ens 7] Epoch=207, Train=0.0136, Val=0.0133
# [Ens 7] Epoch=208, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=209, Train=0.0135, Val=0.0133
# [Ens 7] Epoch=210, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=211, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=212, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=213, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=214, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=215, Train=0.0135, Val=0.0133
# [Ens 7] Epoch=216, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=217, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=218, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=219, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=220, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=221, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=222, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=223, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=224, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=225, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=226, Train=0.0135, Val=0.0132
# [Ens 7] Epoch=227, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=228, Train=0.0135, Val=0.0131
# [Ens 7] Epoch=229, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=230, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=231, Train=0.0134, Val=0.0134
# [Ens 7] Epoch=232, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=233, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=234, Train=0.0134, Val=0.0132
# [Ens 7] Epoch=235, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=236, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=237, Train=0.0134, Val=0.0132
# [Ens 7] Epoch=238, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=239, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=240, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=241, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=242, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=243, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=244, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=245, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=246, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=247, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=248, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=249, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=250, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=251, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=252, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=253, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=254, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=255, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=256, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=257, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=258, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=259, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=260, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=261, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=262, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=263, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=264, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=265, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=266, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=267, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=268, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=269, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=270, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=271, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=272, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=273, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=274, Train=0.0134, Val=0.0131
# [Ens 7] Epoch=275, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=276, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=277, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=278, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=279, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=280, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=281, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=282, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=283, Train=0.0134, Val=0.0130
# [Ens 7] Epoch=284, Train=0.0133, Val=0.0131
# [Ens 7] Epoch=285, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=286, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=287, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=288, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=289, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=290, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=291, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=292, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=293, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=294, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=295, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=296, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=297, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=298, Train=0.0133, Val=0.0130
# [Ens 7] Epoch=299, Train=0.0133, Val=0.0130
# ✅ Saved partial ensemble: TiDE_params_ensemble_partial_7.pkl

# %%
# ====== 경로 먼저 정의 ======
path = ''   # 필요하면 './' 또는 원하는 경로로 수정

# ====== 현재까지 학습된 ensemble 수 ======
n_done = len(ensemble_best_states)   # 보통 1

print(f"Saving partial ensemble: {n_done} model(s)")

# ====== 저장할 dict 구성 ======
sys_params = dict()
sys_params["x_max"] = x_max
sys_params["x_min"] = x_min
sys_params["y_max"] = y_max
sys_params["y_min"] = y_min
sys_params["models_state_dict"] = ensemble_best_states   # 지금은 1개
sys_params["P"] = P
sys_params["window"] = window
sys_params["seeds"] = ensemble_seeds[:n_done]
sys_params["n_ensemble"] = n_done

# ====== 저장 ======
save_name = f'TiDE_params_ensemble_partial_{n_done}.pkl'
with open(path + save_name, 'wb') as f:
    pickle.dump(sys_params, f)

print(f"✅ Saved: {save_name}")
# Out:
# Saving partial ensemble: 7 model(s)
# ✅ Saved: TiDE_params_ensemble_partial_7.pkl

# %%
# Plot loss
loss = save_train_loss
val_loss = save_val_loss
epochs=range(1,len(loss)+1)
plt.figure()
plt.semilogy(epochs, loss,'b', label='Training loss')
plt.semilogy(epochs, val_loss,'r', label='Validation loss')
plt.title('Training and validation losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xscale('log')
#plt.yscale('log')
plt.legend()
#plt.savefig('lossLSTM32.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Plot loss
# ----> 2 loss = save_train_loss
#       3 val_loss = save_val_loss
#       4 epochs=range(1,len(loss)+1)
#
# NameError: name 'save_train_loss' is not defined

# %%
data = {
    'train_loss': loss,
    'val_loss': val_loss
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('loss_save.csv', index=False)

# %%
item = 800 # Select the index for visualizing the results using validation data
#item = 7060
item = 6725



x_plot_past = val_past[item,:,:].unsqueeze(0)
x_plot_future = val_future[item,:,:].unsqueeze(0)
x_plot_val = [x_plot_past, x_plot_future, None]
y_plot_val = val_target[item,:,:].unsqueeze(0)

TiDE_MP.eval()

time1 = time.time()
y_hat = TiDE_MP(x_plot_val)
time2 = time.time()
print(f"forward time = {time2-time1}")

# plot x1
plt.figure()
y_true_original = scaler.inv_scaler_y(y_plot_val.to("cpu")[:,:,:].squeeze().numpy())
plt.plot(y_true_original[0][:,0],label="Original Data")

y_hat_original = scaler.inv_scaler_y(y_hat[:,:,:,1].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_original[0][:,0],label="Median")

y_hat_ub_original = scaler.inv_scaler_y(y_hat[:,:,:,0].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_ub_original[0][:,0],label="Lower quantile")

y_hat_lb_original = scaler.inv_scaler_y(y_hat[:,:,:,2].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_lb_original[0][:,0],label="Upper quantile")

plt.title('Predicted quantile for x1')
plt.xlabel('time step')

# #plt.ylim([3000,4000])
# # plt.xlim([0,19])

plt.fill_between(range(P),
                 y1=y_hat_ub_original[0][:,0],
                 y2=y_hat_lb_original[0][:,0],
                 alpha=0.2, color='gray')
plt.legend()

plt.figure()
plt.plot(y_true_original[0][:,1],label="Original Data")
plt.plot(y_hat_original[0][:,1],label="Median")

y_hat_ub_original = scaler.inv_scaler_y(y_hat[:,:,:,0].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_ub_original[0][:,1],label="Lower quantile")

y_hat_lb_original = scaler.inv_scaler_y(y_hat[:,:,:,2].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_lb_original[0][:,1],label="Upper quantile")
plt.fill_between(range(P),
                 y1=y_hat_ub_original[0][:,1],
                 y2=y_hat_lb_original[0][:,1],
                 alpha=0.2, color='gray')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 12
#       9 x_plot_val = [x_plot_past, x_plot_future, None]
#      10 y_plot_val = val_target[item,:,:].unsqueeze(0)
# ---> 12 TiDE_MP.eval()
#      14 time1 = time.time()
#      15 y_hat = TiDE_MP(x_plot_val)
#
# NameError: name 'TiDE_MP' is not defined

# %%
y_true_original.shape
# Out:
# (1, 50, 2)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
item = 800
item = 9200
# item = 9340 # corner
# item = 56223
# item = 16425 # corner
item = 11575 # corner
# item = 5572 # new layer

x_plot_past = val_past[item,:,:].unsqueeze(0)
x_plot_future = val_future[item,:,:].unsqueeze(0)
x_plot_val = [x_plot_past, x_plot_future, None]
y_plot_val = val_target[item,:,:].unsqueeze(0)

TiDE_MP.eval()

time1 = time.time()
y_hat = TiDE_MP(x_plot_val)
time2 = time.time()
print(f"forward time = {time2-time1}")

# plot x1
y_plot_past = scaler.inv_scaler_y(x_plot_past[:,:,0:2].to("cpu"))

plt.figure(figsize=[12,6])
y_hat_upper = scaler.inv_scaler_y(y_hat[:,:,0:2,2].squeeze().detach().to("cpu").numpy())
y_hat_lower = scaler.inv_scaler_y(y_hat[:,:,0:2,0].squeeze().detach().to("cpu").numpy())
y_true_original = scaler.inv_scaler_y(y_plot_val.to("cpu")[:,:,0:2].squeeze().numpy())
plt.plot(np.linspace(P+1,P*2,P),y_true_original[0][:,0],label="Original Data")
plt.fill_between(np.linspace(P+1,P*2,P),y_hat_lower[0][:,0],y_hat_upper[0][:,0],color = 'gray', alpha = 0.5)

y_hat_original = scaler.inv_scaler_y(y_hat[:,:,0:2,1].squeeze().detach().to("cpu").numpy())
plt.plot(np.linspace(P+1,P*2,P),y_hat_original[0][:,0],label="Median")
plt.plot(np.linspace(1,P,P),y_plot_past[:,:,0].squeeze(0), label="Past")


plt.title('Predicted quantile for x1')
plt.xlabel('time step')


plt.xlim([1,100])

plt.legend()

# =======================================================================

plt.figure(figsize=[12,6])
y_hat_upper = scaler.inv_scaler_y(y_hat[:,:,0:2,2].squeeze().detach().to("cpu").numpy())
y_hat_lower = scaler.inv_scaler_y(y_hat[:,:,0:2,0].squeeze().detach().to("cpu").numpy())
plt.plot(np.linspace(P+1,P*2,P),y_true_original[0][:,1],label="Original Data")
plt.plot(np.linspace(P+1,P*2,P),y_hat_original[0][:,1],label="Median")
plt.plot(np.linspace(1,P,P),y_plot_past[:,:,1].squeeze(0), label="Past")
plt.fill_between(np.linspace(P+1,P*2,P),y_hat_lower[0][:,1],y_hat_upper[0][:,1],color = 'gray', alpha = 0.5)

plt.title('Predicted quantile for x1')
plt.xlabel('time step')


plt.xlim([1,100])

plt.legend()
# Out:
# forward time = 0.023716449737548828
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
aa = y_true_original[:,0]
#aa = y_hat_original[:,0]
#aa = y_plot_past[:,:,0]
aa
# Out:
# array([[ 2.36117098e+03, -4.89795934e-01]])
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

iters = 600

# Set up the figure
fig, ax = plt.subplots(figsize=(9, 4), dpi=100)
ax.set_xlabel("Time",fontsize=14)
ax.set_ylabel("x1",fontsize=14)
line_past, = ax.plot([], [], "-", linewidth=1.5, color="red", label="Past MP Temp")
line_true, = ax.plot([], [], "-", linewidth=1.5, color="green", label="True MP Temp")
line_pred, = ax.plot([], [], "-", linewidth=1.5, color="blue", label="Pred MP Temp")

plt.xlim(1,100)
plt.ylim(1900,4400)

ax.legend(loc='lower right')

# Function to update the plot in each iteration
def update(iter):
    x_plot_past = val_past[iter,:,:].unsqueeze(0)
    x_plot_future = val_future[iter,:,:].unsqueeze(0)
    x_plot_val = [x_plot_past, x_plot_future, None]
    y_plot_val = val_target[iter,:,:].unsqueeze(0)

    TiDE_MP.eval()

    y_hat = TiDE_MP(x_plot_val)


    # plot x1
    y_plot_past = scaler.inv_scaler_y(x_plot_past[:,:,0].to("cpu"))
    y_true_original = scaler.inv_scaler_y(y_plot_val.to("cpu")[:,:,0].squeeze().numpy())
    y_hat_original = scaler.inv_scaler_y(y_hat[:,:,0,1].squeeze().detach().to("cpu").numpy())
    
    line_past.set_data(np.linspace(1,P,P), y_plot_past.T)
    line_true.set_data(np.linspace(P+1,P*2,P), y_true_original.T)
    line_pred.set_data(np.linspace(P+1,P*2,P), y_hat_original.T)
    # ax.collections[-1].remove()
    plt.title(f"step {iter}")
    return line_past, line_pred, line_true

animation = FuncAnimation(fig, update, frames=iters,  blit=True)

# # Show the animation
HTML(animation.to_jshtml())
plt.rcParams["animation.html"] = "jshtml"
animation.save('validation.gif', writer='imagemagick', fps=10)
animation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 43
#      40     plt.title(f"step {iter}")
#      41     return line_past, line_pred, line_true
# ---> 43 animation = FuncAnimation(fig, update, frames=iters,  blit=True)
#      45 # # Show the animation
#      46 HTML(animation.to_jshtml())
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1695, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1692 # Needs to be initialized so the draw functions work without checking
#    1693 self._save_seq = []
# -> 1695 super().__init__(fig, **kwargs)
#    1697 # Need to reset the saved seq, since right now it will contain data
#    1698 # for a single frame from init, which is not what we want.
#    1699 self._save_seq = []
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1417, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1415 if event_source is None:
#    1416     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1417 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:888, in Animation.__init__(self, fig, event_source, blit)
#     885 self._close_id = self._fig.canvas.mpl_connect('close_event',
#     886                                               self._stop)
#     887 if self._blit:
# --> 888     self._setup_blit()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1211, in Animation._setup_blit(self)
#    1209 self._drawn_artists = []
#    1210 # _post_draw needs to be called first to initialize the renderer
# -> 1211 self._post_draw(None, self._blit)
#    1212 # Then we need to clear the Frame for the initial draw
#    1213 # This is typically handled in _on_resize because QT and Tk
#    1214 # emit a resize event on launch, but the macosx backend does not,
#    1215 # thus we force it here for everyone for consistency
#    1216 self._init_draw()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1166, in Animation._post_draw(self, framedata, blit)
#    1164     self._blit_draw(self._drawn_artists)
#    1165 else:
# -> 1166     self._fig.canvas.draw_idle()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/figure.py:3164, in Figure.draw(self, renderer)
#    3161 finally:
#    3162     self.stale = False
# -> 3164 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/backend_bases.py:1271, in Event._process(self)
#    1269 def _process(self):
#    1270     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1271     self.canvas.callbacks.process(self.name, self)
#    1272     self._guiEvent_deleted = True
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:912, in Animation._start(self, *args)
#     909 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     911 # Now do any initial draw
# --> 912 self._init_draw()
#     914 # Add our callback for stepping the animation and
#     915 # actually start the event_source.
#     916 self.event_source.add_callback(self._step)
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1749, in FuncAnimation._init_draw(self)
#    1741         warnings.warn(
#    1742             "Can not start iterating the frames for the initial draw. "
#    1743             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1746             "it may be exhausted due to a previous display or save."
#    1747         )
#    1748         return
# -> 1749     self._draw_frame(frame_data)
#    1750 else:
#    1751     self._drawn_artists = self._init_func()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1768, in FuncAnimation._draw_frame(self, framedata)
#    1764     self._save_seq = self._save_seq[-self._save_count:]
#    1766 # Call the func with framedata and args. If blitting is desired,
#    1767 # func needs to return a sequence of any artists that were modified.
# -> 1768 self._drawn_artists = self._func(framedata, *self._args)
#    1770 if self._blit:
#    1772     err = RuntimeError('The animation function must return a sequence '
#    1773                        'of Artist objects.')
#
# Cell In[64], line 32, in update(iter)
#      28 y_hat = TiDE_MP(x_plot_val)
#      31 # plot x1
# ---> 32 y_plot_past = scaler.inv_scaler_y(x_plot_past[:,:,0].to("cpu"))
#      33 y_true_original = scaler.inv_scaler_y(y_plot_val.to("cpu")[:,:,0].squeeze().numpy())
#      34 y_hat_original = scaler.inv_scaler_y(y_hat[:,:,0,1].squeeze().detach().to("cpu").numpy())
#
# Cell In[48], line 31, in scalers.inv_scaler_y(self, y_s)
#      30 def inv_scaler_y(self, y_s):
# ---> 31     return (y_s + 1)*0.5*(self.y_max-self.y_min) + self.y_min
#
# ValueError: operands could not be broadcast together with shapes (1,50) (1,1,2)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Evaluation

# %%
def sMAPE(y_true,y_hat):
    MAPE_ind = 100* np.mean(np.abs((y_true - y_hat) / (np.abs(y_true)+np.abs(y_hat))))
    return MAPE_ind

def SSE_compute(y_true, y_hat):
    return np.sum((y_true - y_hat)**2)

# Main code for eval
MAPE_x1 = np.empty((val_past.shape[0]))
MAPE_x2 = np.empty((val_past.shape[0]))

SSE_x1 = 0
SSE_x2 = 0


for item in tqdm(range(val_past.shape[0])):
    x_past = val_past[item,:,:].unsqueeze(0)
    x_future = val_future[item,:,:].unsqueeze(0)
    x_val = [x_past, x_future, None]
    y_val = val_target[item,:,:].unsqueeze(0)
    y_hat = TiDE_MP(x_val)
    # sMAPE
    MAPE_x1[item] = (sMAPE(y_val.to("cpu")[:,:,0].squeeze().numpy(), y_hat[:,:,0,1].squeeze().detach().to("cpu").numpy()))
    MAPE_x2[item] = (sMAPE(y_val.to("cpu")[:,:,1].squeeze().numpy(), y_hat[:,:,1,1].squeeze().detach().to("cpu").numpy()))

    # RMSE
    SSE_x1 = SSE_x1 + SSE_compute(y_val.to("cpu")[:,:,0].squeeze().numpy(), y_hat[:,:,0,1].squeeze().detach().to("cpu").numpy())
    SSE_x2 = SSE_x2 + SSE_compute(y_val.to("cpu")[:,:,1].squeeze().numpy(), y_hat[:,:,1,1].squeeze().detach().to("cpu").numpy())


n_item = val_past.shape[0] * val_past.shape[1]
RRMSE_x1 = np.sqrt(np.sum(SSE_x1)/n_item/np.var(y_s_val[:,0]))*100
RRMSE_x2 = np.sqrt(np.sum(SSE_x1)/n_item/np.var(y_s_val[:,1]))*100

MAPE_x1 = np.mean(MAPE_x1)
MAPE_x2 = np.mean(MAPE_x2)

print(f"MAPE_x1 = {MAPE_x1:.2f}%, MAPE_x2 = {MAPE_x2:.2f}%")   
print(f"RRMSE_x1 = {RRMSE_x1:.2f}, RRMSE_x2 = {RRMSE_x2:.2f}")  

# ccc
# Out:
# 100%|██████████| 60942/60942 [01:44<00:00, 583.01it/s]
# MAPE_x1 = 1.24%, MAPE_x2 = 4.25%
# RRMSE_x1 = 5.15, RRMSE_x2 = 4.49
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
