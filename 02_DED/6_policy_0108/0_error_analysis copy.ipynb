# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

def plot_saved_outputs(save_dir, laser_num, N_step=None, label=None):
    # label 없으면 폴더명 마지막 사용
    if label is None:
        label = os.path.basename(save_dir)

    # Load data
    x_path = os.path.join(save_dir, f"x_outputs_laser_{laser_num}.csv")
    u_path = os.path.join(save_dir, f"u_outputs_laser_{laser_num}.csv")
    ref_path = os.path.join(save_dir, f"ref_laser_{laser_num}.csv")

    try:
        x = pd.read_csv(x_path).values
        u = pd.read_csv(u_path).values
        ref = pd.read_csv(ref_path).values.flatten()

        if N_step is None:
            N_step = min(len(x), len(u), len(ref))

        plt.figure(figsize=[8, 6])
        # 🔹 이름은 label만 사용
        plt.suptitle(label, fontsize=14)

        # ─── 1. Melt Pool Temperature ──────────────────────────────
        plt.subplot(3, 1, 1)
        plt.plot(x[:N_step, 0], label="GAMMA simulation")
        plt.plot(ref[:N_step], label="Reference")
        for yline in [2000, 3000, 4000]:
            plt.axhline(y=yline, color='gray', linestyle='--', linewidth=0.8)

        plt.ylabel("Melt Pool Temp (K)")
        plt.legend()

        # ─── 2. Melt Pool Depth ───────────────────────────────────
        plt.subplot(3, 1, 2)
        plt.plot(x[:N_step, 1], label="GAMMA simulation")
        plt.axhline(y=0.225, linestyle='--', color='r', label="Upper Bound")
        plt.axhline(y=0.075, linestyle='--', color='r', label="Lower Bound")

        plt.ylabel("Melt Pool Depth (mm)")
        plt.legend()

        # ─── 3. Laser Power ───────────────────────────────────────
        plt.subplot(3, 1, 3)
        plt.plot(u[:N_step])
        for yline in [500, 600, 700]:
            plt.axhline(y=yline, color='gray', linestyle='--', linewidth=0.8)

        plt.xlabel("MPC time step")
        plt.ylabel("Laser Power (W)")

        plt.tight_layout(rect=[0, 0, 1, 0.95])
        plt.show()

    except Exception as e:
        print(f"❌ Failed to plot ({label}): {e}")

# %% [markdown]
# ## baseline

# %%
import os

save_dirs = [
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline/simulation/policy_model_3L_1024H_s1_c0",
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline/simulation/policy_model_3L_1024H_s1_c1",
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline_rollout1_m2048_epoch50/simulation/policy_model_case00_3L_1024H_s1_c3_base",
    #"/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline/simulation/policy_model_3L_1024H_s1_c3",
]

target_laser_num = 2

for save_dir in save_dirs:
    if not os.path.exists(save_dir):
        continue

    # 👉 폴더 경로의 맨 마지막 이름
    label = os.path.basename(save_dir)

    print(f"📊 Plotting laser {target_laser_num} | {label}")
    plot_saved_outputs(save_dir, target_laser_num, label=label)
# Out:
# 📊 Plotting laser 2 | policy_model_3L_1024H_s1_c0
# 📊 Plotting laser 2 | policy_model_3L_1024H_s1_c1
# 📊 Plotting laser 2 | policy_model_case00_3L_1024H_s1_c3_base

# %% [markdown]
# ## augment_c1

# %%
import os

save_dirs = [
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline_rollout1_m256_epoch50/simulation/aug",
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline_rollout1_m10240_epoch50/simulation/policy_model_case00_3L_1024H_s1_c1_aug",
]

target_laser_num = 2

for save_dir in save_dirs:
    if not os.path.exists(save_dir):
        continue

    # 👉 폴더 경로의 맨 마지막 이름
    label = os.path.basename(
    os.path.dirname(
        os.path.dirname(save_dir)
    )
)


    print(f"📊 Plotting laser {target_laser_num} | {label}")
    plot_saved_outputs(save_dir, target_laser_num, label=label)
# Out:
# 📊 Plotting laser 2 | baseline_rollout1_m256_epoch50
# 📊 Plotting laser 2 | baseline_rollout1_m10240_epoch50

# %% [markdown]
# ## augment_c3

# %%
import os

save_dirs = [
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline_rollout1_m2048_epoch50/simulation/policy_model_case00_3L_1024H_s1_c3_aug",
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline_rollout1_m10240_epoch50/simulation/policy_model_case00_3L_1024H_s1_c3_aug",
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/baseline_rollout8_m204800_epoch24/simulation/policy_model_case00_3L_1024H_s1_c3_aug",
]

target_laser_num = 2

for save_dir in save_dirs:
    if not os.path.exists(save_dir):
        continue

    # 👉 폴더 경로의 맨 마지막 이름
    label = os.path.basename(
    os.path.dirname(
        os.path.dirname(save_dir)
    )
)


    print(f"📊 Plotting laser {target_laser_num} | {label}")
    plot_saved_outputs(save_dir, target_laser_num, label=label)
# Out:
# 📊 Plotting laser 2 | baseline_rollout1_m2048_epoch50
# 📊 Plotting laser 2 | baseline_rollout1_m10240_epoch50
# 📊 Plotting laser 2 | baseline_rollout8_m204800_epoch24

# %% [markdown]
# ## augment_c3_replacement

# %%
import os

save_dirs = [
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/aug_replace/simulation_outputs_0103_DPC_ro100_ep10_L3_H512_wt1.0_ws1.0_wc3.0_rollout0010",
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/aug_replace/simulation_outputs_0103_DPC_ro100_ep10_L3_H512_wt1.0_ws1.0_wc3.0_rollout0030",
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/aug_replace/simulation_outputs_0103_DPC_ro100_ep10_L3_H512_wt1.0_ws1.0_wc3.0_rollout0070",
    "/home/ftk3187/github/DPC_research/02_DED/6_policy_0108/experiments/aug_replace/simulation_outputs_0103_DPC_ro100_ep10_L3_H512_wt1.0_ws1.0_wc3.0_rollout0095",
]

target_laser_num = 2

for save_dir in save_dirs:
    if not os.path.exists(save_dir):
        continue

    # 👉 폴더 경로의 맨 마지막 이름
    label = os.path.basename(save_dir)



    print(f"📊 Plotting laser {target_laser_num} | {label}")
    plot_saved_outputs(save_dir, target_laser_num, label=label)
# Out:
# 📊 Plotting laser 2 | simulation_outputs_0103_DPC_ro100_ep10_L3_H512_wt1.0_ws1.0_wc3.0_rollout0010
# 📊 Plotting laser 2 | simulation_outputs_0103_DPC_ro100_ep10_L3_H512_wt1.0_ws1.0_wc3.0_rollout0030
# 📊 Plotting laser 2 | simulation_outputs_0103_DPC_ro100_ep10_L3_H512_wt1.0_ws1.0_wc3.0_rollout0070
# 📊 Plotting laser 2 | simulation_outputs_0103_DPC_ro100_ep10_L3_H512_wt1.0_ws1.0_wc3.0_rollout0095
